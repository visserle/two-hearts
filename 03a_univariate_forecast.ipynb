# %% [markdown]
# # Questioning the Effect of Physiological Heartbeat Synchrony in Romantic Dyads. A Preregistered Deep Learning Analysis.

# %% [markdown]
# ### For Google Colab only:

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Deep Learning

# %%
import os
import datetime

import IPython
import IPython.display
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from numpy import array
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import RepeatVector, TimeDistributed

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

from lists import list_str, datafiles, datafiles_1k, datafiles_google

tf.version.VERSION
# Out:
# '2.3.0'

# %%
# Load data
data = [None]*len(list_str)
for i in range(len(list_str)):
    data[i] = np.load(datafiles[i])
    #data_raw[i] = np.load(datafiles_google[i])

# Data preperation for keras
data = np.array(data, dtype = "float32")
data.shape
# Out:
# (70, 30000)

# %% [markdown]
# ### Univariate

# %%
# # try with higher sampling rate
# data = np.load(datafiles_1k[0])
# data = np.array(data, dtype = "float32")
# data.shape

# # Downsampling to 200 Hz
# data = data[::5]
# len(data)

# %%
# Setting sampling rate
sampling_rate = 100
print("Sampling rate:", sampling_rate)

# split a univariate sequence into samples
def split_sequence(sequence, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequence)):
        if i % (sampling_rate/2) == 0: # to reduce redundancy in ECG-data ## maybe even ==sampling_rate to *remove* redundancy?
            # find the end of this pattern
            end_ix = i + n_steps_in
            out_end_ix = end_ix + n_steps_out
            # check if we are beyond the sequence
            if out_end_ix > len(sequence):
                break
            # gather input and output parts of the pattern
            seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
            X.append(seq_x)
            y.append(seq_y)
    return array(X), array(y)

# choose a number of time steps
n_steps_in, n_steps_out = 3*sampling_rate, 1*sampling_rate
# split into samples
'''only for 1 participant so far'''
X, y = split_sequence(data[0], n_steps_in, n_steps_out)
# summarize the data
print(len(data[0]))

# 3D-Data. X = Input, y = output

# reshape from [samples, timesteps] into [samples, timesteps, features]
n_features = 1
X = X.reshape((X.shape[0], X.shape[1], n_features))
y = y.reshape((y.shape[0], y.shape[1], n_features))
print(X.shape,y.shape)
#plt.plot(y[3,:,0])
print(type(X))
X.dtype

test = np.append(X[3,:,:], y[3,:,:])
plt.plot(test)
# Out:
# Sampling rate: 100
# 30000
# (593, 300, 1) (593, 100, 1)
# <class 'numpy.ndarray'>

# %%
# Data split
print(X.shape,y.shape)

num_train_samples = int(0.5 * len(X))
num_val_samples = int(0.25 * len(X))
num_test_samples = len(X) - num_train_samples - num_val_samples
print("num_train_samples:", num_train_samples)
print("num_val_samples:", num_val_samples)
print("num_test_samples:", num_test_samples)

X_train = X[:num_train_samples]
y_train = y[:num_train_samples]
X_vali =  X[num_train_samples:(num_train_samples+num_val_samples)]
y_vali = y[num_train_samples:(num_train_samples+num_val_samples)]
X_test = X[(num_train_samples+num_val_samples):]
y_test = y[(num_train_samples+num_val_samples):]

print(len(X_train),len(X_vali),len(X_test))
# Out:
# (593, 300, 1) (593, 100, 1)
# num_train_samples: 296
# num_val_samples: 148
# num_test_samples: 149
# 296 148 149

# %%
# define model
model = Sequential()
model.add(LSTM(300, activation='relu', return_sequences=True, input_shape=(n_steps_in,n_features)))
model.add(LSTM(100, activation='relu'))
#model.add(LSTM(100, activation='relu'))
model.add(Dense(n_steps_out))
model.compile(optimizer='adam', loss='mse', metrics=["mse"]) # accuracy does not work; mean squared (!!!)

# %%
# fit model
history = model.fit(X_train, y_train, epochs=64, batch_size=32, verbose=1, validation_data=(X_vali, y_vali))
# Out:
# Epoch 1/64
# 10/10 [==============================] - 16s 2s/step - loss: 0.0063 - mae: 0.0545 - val_loss: 0.0063 - val_mae: 0.0545
# Epoch 2/64
# 10/10 [==============================] - 16s 2s/step - loss: 0.0062 - mae: 0.0542 - val_loss: 0.0063 - val_mae: 0.0543
# Epoch 3/64
# 10/10 [==============================] - 16s 2s/step - loss: 0.0062 - mae: 0.0538 - val_loss: 0.0062 - val_mae: 0.0540
# Epoch 4/64
# 10/10 [==============================] - 15s 1s/step - loss: 0.0061 - mae: 0.0531 - val_loss: 0.0061 - val_mae: 0.0528
# Epoch 5/64
# 10/10 [==============================] - 15s 2s/step - loss: 0.0059 - mae: 0.0518 - val_loss: 0.0060 - val_mae: 0.0513
# Epoch 6/64
# 10/10 [==============================] - 14s 1s/step - loss: 0.0058 - mae: 0.0505 - val_loss: 0.0058 - val_mae: 0.0502
# Epoch 7/64
# 10/10 [==============================] - 15s 2s/step - loss: 0.0056 - mae: 0.0488 - val_loss: 0.0056 - val_mae: 0.0480
# Epoch 8/64
# 10/10 [==============================] - 15s 1s/step - loss: 0.0054 - mae: 0.0471 - val_loss: 0.0056 - val_mae: 0.0471
# Epoch 9/64
# 10/10 [==============================] - 16s 2s/step - loss: 0.0054 - mae: 0.0466 - val_loss: 0.0055 - val_mae: 0.0464
# Epoch 10/64
# 10/10 [==============================] - 17s 2s/step - loss: 0.0053 - mae: 0.0459 - val_loss: 0.0054 - val_mae: 0.0460
# Epoch 11/64
# 10/10 [==============================] - 18s 2s/step - loss: 0.0052 - mae: 0.0455 - val_loss: 0.0054 - val_mae: 0.0456
# Epoch 12/64
# 10/10 [==============================] - 20s 2s/step - loss: 0.0052 - mae: 0.0453 - val_loss: 0.0054 - val_mae: 0.0454
# Epoch 13/64
# 10/10 [==============================] - 18s 2s/step - loss: 0.0051 - mae: 0.0447 - val_loss: 0.0053 - val_mae: 0.0450
# Epoch 14/64
# 10/10 [==============================] - 18s 2s/step - loss: 0.0051 - mae: 0.0441 - val_loss: 0.0052 - val_mae: 0.0443
# Epoch 15/64
# 10/10 [==============================] - 17s 2s/step - loss: 0.0050 - mae: 0.0435 - val_loss: 0.0052 - val_mae: 0.0437
# Epoch 16/64
# 10/10 [==============================] - 17s 2s/step - loss: 0.0050 - mae: 0.0432 - val_loss: 0.0052 - val_mae: 0.0436
# Epoch 17/64
# 10/10 [==============================] - 17s 2s/step - loss: 0.0050 - mae: 0.0430 - val_loss: 0.0052 - val_mae: 0.0432
# Epoch 18/64
# 10/10 [==============================] - 18s 2s/step - loss: 0.0049 - mae: 0.0428 - val_loss: 0.0052 - val_mae: 0.0433
# Epoch 19/64
# 10/10 [==============================] - 15s 2s/step - loss: 0.0049 - mae: 0.0426 - val_loss: 0.0052 - val_mae: 0.0432
# Epoch 20/64
# 10/10 [==============================] - 15s 1s/step - loss: 0.0049 - mae: 0.0422 - val_loss: 0.0051 - val_mae: 0.0429
# Epoch 21/64
# 10/10 [==============================] - 15s 1s/step - loss: 0.0049 - mae: 0.0422 - val_loss: 0.0051 - val_mae: 0.0426
# Epoch 22/64
# 10/10 [==============================] - 14s 1s/step - loss: 0.0048 - mae: 0.0418 - val_loss: 0.0050 - val_mae: 0.0423
# Epoch 23/64
# 10/10 [==============================] - 16s 2s/step - loss: 0.0048 - mae: 0.0415 - val_loss: 0.0050 - val_mae: 0.0418
# Epoch 24/64
# 10/10 [==============================] - 17s 2s/step - loss: 0.0048 - mae: 0.0412 - val_loss: 0.0050 - val_mae: 0.0414
# Epoch 25/64
# 10/10 [==============================] - 19s 2s/step - loss: 0.0048 - mae: 0.0410 - val_loss: 0.0050 - val_mae: 0.0412
# Epoch 26/64
# 10/10 [==============================] - 16s 2s/step - loss: 0.0048 - mae: 0.0409 - val_loss: 0.0049 - val_mae: 0.0411
# Epoch 27/64
# 10/10 [==============================] - 16s 2s/step - loss: 0.0047 - mae: 0.0406 - val_loss: 0.0049 - val_mae: 0.0409
# Epoch 28/64
# 10/10 [==============================] - 19s 2s/step - loss: 0.0047 - mae: 0.0406 - val_loss: 0.0050 - val_mae: 0.0416
# Epoch 29/64
# 10/10 [==============================] - 20s 2s/step - loss: 0.0047 - mae: 0.0406 - val_loss: 0.0049 - val_mae: 0.0412
# Epoch 30/64
# 10/10 [==============================] - 17s 2s/step - loss: 0.0047 - mae: 0.0403 - val_loss: 0.0050 - val_mae: 0.0418
# Epoch 31/64
# 10/10 [==============================] - 15s 2s/step - loss: 0.0047 - mae: 0.0402 - val_loss: 0.0049 - val_mae: 0.0409
# Epoch 32/64
# 10/10 [==============================] - 15s 2s/step - loss: 0.0046 - mae: 0.0397 - val_loss: 0.0048 - val_mae: 0.0402
# Epoch 33/64
# 10/10 [==============================] - 16s 2s/step - loss: 0.0046 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0403
# Epoch 34/64
# 10/10 [==============================] - 15s 2s/step - loss: 0.0046 - mae: 0.0396 - val_loss: 0.0048 - val_mae: 0.0402
# Epoch 35/64
# 10/10 [==============================] - 17s 2s/step - loss: 0.0046 - mae: 0.0393 - val_loss: 0.0048 - val_mae: 0.0398
# Epoch 36/64
# 10/10 [==============================] - 19s 2s/step - loss: 0.0046 - mae: 0.0394 - val_loss: 0.0048 - val_mae: 0.0401
# Epoch 37/64
# 10/10 [==============================] - 19s 2s/step - loss: 0.0045 - mae: 0.0391 - val_loss: 0.0048 - val_mae: 0.0403
# Epoch 38/64
# 10/10 [==============================] - 18s 2s/step - loss: 0.0045 - mae: 0.0391 - val_loss: 0.0047 - val_mae: 0.0396
# Epoch 39/64
# 10/10 [==============================] - 18s 2s/step - loss: 0.0045 - mae: 0.0389 - val_loss: 0.0048 - val_mae: 0.0399
# Epoch 40/64
# 10/10 [==============================] - 16s 2s/step - loss: 0.0045 - mae: 0.0387 - val_loss: 0.0047 - val_mae: 0.0394
# Epoch 41/64
# 10/10 [==============================] - 21s 2s/step - loss: 0.0045 - mae: 0.0385 - val_loss: 0.0047 - val_mae: 0.0392
# Epoch 42/64
# 10/10 [==============================] - 18s 2s/step - loss: 0.0045 - mae: 0.0386 - val_loss: 0.0047 - val_mae: 0.0399
# Epoch 43/64
# 10/10 [==============================] - 18s 2s/step - loss: 0.0045 - mae: 0.0384 - val_loss: 0.0047 - val_mae: 0.0389
# Epoch 44/64
# 10/10 [==============================] - 18s 2s/step - loss: 0.0044 - mae: 0.0382 - val_loss: 0.0047 - val_mae: 0.0394
# Epoch 45/64
# 10/10 [==============================] - 15s 2s/step - loss: 0.0044 - mae: 0.0384 - val_loss: 0.0047 - val_mae: 0.0388
# Epoch 46/64
# 10/10 [==============================] - 19s 2s/step - loss: 0.0044 - mae: 0.0380 - val_loss: 0.0046 - val_mae: 0.0386
# Epoch 47/64
# 10/10 [==============================] - 25s 3s/step - loss: 0.0044 - mae: 0.0378 - val_loss: 0.0047 - val_mae: 0.0390
# Epoch 48/64
# 10/10 [==============================] - 26s 3s/step - loss: 0.0044 - mae: 0.0380 - val_loss: 0.0047 - val_mae: 0.0390
# Epoch 49/64
# 10/10 [==============================] - 26s 3s/step - loss: 0.0044 - mae: 0.0381 - val_loss: 0.0047 - val_mae: 0.0392
# Epoch 50/64
# 10/10 [==============================] - 25s 3s/step - loss: 0.0044 - mae: 0.0379 - val_loss: 0.0047 - val_mae: 0.0389
# Epoch 51/64
# 10/10 [==============================] - 27s 3s/step - loss: 0.0043 - mae: 0.0373 - val_loss: 0.0046 - val_mae: 0.0385
# Epoch 52/64
# 10/10 [==============================] - 18s 2s/step - loss: 0.0044 - mae: 0.0378 - val_loss: 0.0046 - val_mae: 0.0385
# Epoch 53/64
# 10/10 [==============================] - 16s 2s/step - loss: 0.0044 - mae: 0.0378 - val_loss: 0.0046 - val_mae: 0.0384
# Epoch 54/64
# 10/10 [==============================] - 16s 2s/step - loss: 0.0043 - mae: 0.0377 - val_loss: 0.0046 - val_mae: 0.0385
# Epoch 55/64
# 10/10 [==============================] - 16s 2s/step - loss: 0.0043 - mae: 0.0377 - val_loss: 0.0046 - val_mae: 0.0387
# Epoch 56/64
# 10/10 [==============================] - 17s 2s/step - loss: 0.0043 - mae: 0.0377 - val_loss: 0.0046 - val_mae: 0.0384
# Epoch 57/64
# 10/10 [==============================] - 17s 2s/step - loss: 0.0043 - mae: 0.0373 - val_loss: 0.0046 - val_mae: 0.0384
# Epoch 58/64
# 10/10 [==============================] - 25s 2s/step - loss: 0.0043 - mae: 0.0376 - val_loss: 0.0046 - val_mae: 0.0379
# Epoch 59/64
# 10/10 [==============================] - 27s 3s/step - loss: 0.0043 - mae: 0.0372 - val_loss: 0.0046 - val_mae: 0.0380
# Epoch 60/64
# 10/10 [==============================] - 28s 3s/step - loss: 0.0043 - mae: 0.0371 - val_loss: 0.0046 - val_mae: 0.0382
# Epoch 61/64
# 10/10 [==============================] - 25s 2s/step - loss: 0.0043 - mae: 0.0373 - val_loss: 0.0046 - val_mae: 0.0382
# Epoch 62/64
# 10/10 [==============================] - 17s 2s/step - loss: 0.0043 - mae: 0.0375 - val_loss: 0.0046 - val_mae: 0.0385
# Epoch 63/64
# 10/10 [==============================] - 16s 2s/step - loss: 0.0043 - mae: 0.0370 - val_loss: 0.0046 - val_mae: 0.0379
# Epoch 64/64
# 10/10 [==============================] - 16s 2s/step - loss: 0.0042 - mae: 0.0369 - val_loss: 0.0046 - val_mae: 0.0380

# %%
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.clf()
mae = history_dict["mae"]
val_mae = history_dict["val_mae"]
plt.plot(epochs, mae, "bo", label="Training mae")
plt.plot(epochs, val_mae, "b", label="Validation mae")
plt.title("Training and validation mean absolute error")
plt.xlabel("Epochs")
plt.ylabel("Mean absolute error")
plt.legend()
plt.show()

# %%
# model demonstration

trial = 10

# demonstrate training
yhat = model.predict(X_train,batch_size=10)

test = np.append(X_train[trial],yhat[trial])
test2 = np.append(X_train[trial],y_train[trial])

plt.figure(1)
plt.plot(test)
plt.plot(test2)

# demonstrate prediction
yhat = model.predict(X_test,batch_size=10)

test = np.append(X_test[trial],yhat[trial])
test2 = np.append(X_test[trial],y_test[trial])

plt.figure(2)
plt.plot(test)
plt.plot(test2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16640/3375762062.py in <module>
#       4
#       5 # demonstrate training
# ----> 6 yhat = model.predict(X_train,batch_size=10)
#       7
#       8 test = np.append(X_train[trial],yhat[trial])
#
# NameError: name 'model' is not defined

# %%
#tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=False)
