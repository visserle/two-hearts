# %% [markdown]
# # Questioning the Effect of Physiological Heartbeat Synchrony in Romantic Dyads. A Preregistered Deep Learning Analysis.

# %%
# For Google Colab / local machine
import tensorflow.keras
ver = tensorflow.version.VERSION

if float(ver[:3]) > 2.7:
  print("Latest TensorFlow version detected -> Prepare Google Colab usage\n")
  google_colab = 1
  from google.colab import drive
  drive.mount('/content/drive/')
  colab_path = "/content/drive/MyDrive/Masterarbeit/Code/two-hearts/"
  import sys
  sys.path.append(colab_path)
else:
  colab_path = ""

# %%
# Import libraries
import os
import datetime
import random
import pickle
import IPython
import IPython.display
import numpy as np
from numpy import array, hstack
import pandas as pd
from copy import deepcopy
import matplotlib.pyplot as plt
from tensorflow.python.keras.layers import deserialize, serialize
from tensorflow.python.keras.saving import saving_utils
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import LSTM, Dense, RepeatVector, TimeDistributed, Input, BatchNormalization, multiply, concatenate, Flatten, Activation, dot
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping
import pydot as pyd
from tensorflow.keras.utils import plot_model, model_to_dot
tensorflow.keras.utils.pydot = pyd

from lists import dyads, num_dyads, participants, num_participants

print("TensorFlow version:",tensorflow.version.VERSION)
# Out:
# TensorFlow version: 2.6.0

# %% [markdown]
# ## Deep Learning

# %%
# Set sampling rate
sampling_rate = 50
print("Sampling rate:", sampling_rate)

# Set number of time steps
n_steps_in, n_steps_out = 5*sampling_rate, 2*sampling_rate
print("Time steps:", n_steps_in, n_steps_out)

# Set conditions
condition = ["sit","gaze","gaze_swap"]
print("Conditions:", condition)

# Show number of participants
print("Participants:", num_participants)

# Show number of dyads
print("Dyads:", num_dyads)

# Set number of trials
trial = ["01","02","03"]
print("Number of training trials:",len(trial))
# Out:
# Sampling rate: 50
# Time steps: 250 100
# Conditions: ['sit', 'gaze', 'gaze_swap']
# Participants: 4
# Dyads: 2
# Number of training trials: 3

# %%
# Prepare sample data
def sample_preperation(condition):

    # Load data
    data = np.load(f"{colab_path}data/data_{condition}.npy")
    print(f"Loaded data with shape {data.shape} and type {data.dtype}")

    # Create empty samples
    X_input_train = X_input_vali = X_input_test = np.empty((0, n_steps_in, 2))
    y_output_train = y_output_vali = y_output_test = np.empty((0, n_steps_out, 2))

    # Split a multivariate sequence into samples (modified from Brownlee 2018, p.156)
    def split_sequences(sequences, n_steps_in, n_steps_out):
        X, y = list(), list()
        for i in range(len(sequences)):
            if i % (sampling_rate) == 0: # to remove redundancy in samples
                # find the end of this pattern
                end_ix = i + n_steps_in
                out_end_ix = end_ix + n_steps_out
                # check if we are beyond the dataset
                if out_end_ix > len(sequences):
                    break
                # gather input and output parts of the pattern
                seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix:out_end_ix, :]
                X.append(seq_x)
                y.append(seq_y)
        return array(X), array(y)

    for i, idx in enumerate(list(range(num_participants))[::2]): # index for dyads
        # define input sequence
        in_seq1 = data[idx]
        in_seq2 = data[idx+1]
        # convert to [rows, columns] structure
        in_seq1 = in_seq1.reshape((len(in_seq1), 1))
        in_seq2 = in_seq2.reshape((len(in_seq2), 1))
        # horizontally stack columns
        dataset = hstack((in_seq1, in_seq2))
        # covert into input/output
        X, y = split_sequences(dataset, n_steps_in, n_steps_out)
        # data split
        num_train_samples = int(0.6 * len(X))
        num_val_samples = int(0.2 * len(X))
        num_test_samples = len(X) - num_train_samples - num_val_samples
        # append data for multiple dyads
        X_input_train = np.append(X_input_train,X[:num_train_samples],axis=0)
        y_output_train = np.append(y_output_train,y[:num_train_samples],axis=0)
        X_input_vali = np.append(X_input_vali,X[num_train_samples:(num_train_samples+num_val_samples)],axis=0)
        y_output_vali = np.append(y_output_vali,y[num_train_samples:(num_train_samples+num_val_samples)],axis=0)
        X_input_test = np.append(X_input_test,X[(num_train_samples+num_val_samples):],axis=0)
        y_output_test = np.append(y_output_test,y[(num_train_samples+num_val_samples):],axis=0)
        
    # Create dictionary
    samples = {
        "X_input_train": X_input_train,
        "y_output_train": y_output_train,
        "X_input_vali": X_input_vali,
        "y_output_vali": y_output_vali,
        "X_input_test": X_input_test,
        "y_output_test": y_output_test
    }
    
    print("Length of samples for each set:", len(X_input_train), len(X_input_vali), len(X_input_test))

    return samples

# %%
# Define simple seq2seq model 
# Modified from Wieniawska 2020 
# (https://levelup.gitconnected.com/building-seq2seq-lstm-with-luong-attention-in-keras-for-time-series-forecasting-1ee00958decb)

def lstm_decoder_encoder(samples, n_hidden = 100):
    # Input layer
    input_train = Input(shape=(samples["X_input_train"].shape[1], samples["X_input_train"].shape[2]))
    output_train = Input(shape=(samples["y_output_train"].shape[1], samples["y_output_train"].shape[2]))

    # Encoder LSTM with state_h and state_c
    encoder_last_h1, encoder_last_h2, encoder_last_c = LSTM(
    n_hidden, activation='elu', dropout=0.2, recurrent_dropout=0.2, 
    return_sequences=False, return_state=True)(input_train)

    # Batch normalisation to avoid gradient explosion
    encoder_last_h1 = BatchNormalization(momentum=0.6)(encoder_last_h1)
    encoder_last_c = BatchNormalization(momentum=0.6)(encoder_last_c)

    # Decoder LSTM
    decoder = RepeatVector(output_train.shape[1])(encoder_last_h1)
    decoder = LSTM(n_hidden, activation='elu', dropout=0.2, recurrent_dropout=0.2, return_state=False, return_sequences=True)(
        decoder, initial_state=[encoder_last_h1, encoder_last_c])

    # Dense layer with repeated weights
    out = TimeDistributed(Dense(output_train.shape[2]))(decoder)

    # Compile model
    model = Model(inputs=input_train, outputs=out)
    opt = Adam(learning_rate=0.001, clipnorm=1)
    model.compile(optimizer=opt, loss='mean_squared_error', metrics=['mae'])
    print(model)

    return model

# %%
# Define seq2seq model with Luong attention
# Modified from Wieniawska 2020 
# (https://levelup.gitconnected.com/building-seq2seq-lstm-with-luong-attention-in-keras-for-time-series-forecasting-1ee00958decb)

def lstm_decoder_encoder_luong_attention(samples, n_hidden = 100):
    # Input layer
    input_train = Input(shape=(samples["X_input_train.shape[1]"], samples["X_input_train.shape[2]"]))
    output_train = Input(shape=(samples["y_output_train.shape[1]"], samples["y_output_train.shape[2]"]))

    # Encoder LSTM
    encoder_stack_h, encoder_last_h, encoder_last_c = LSTM(
        n_hidden, activation='elu', dropout=0.2, recurrent_dropout=0.2, 
        return_state=True, return_sequences=True)(input_train)

    # Batch normalisation to avoid gradient explosion
    encoder_last_h = BatchNormalization(momentum=0.6)(encoder_last_h)
    encoder_last_c = BatchNormalization(momentum=0.6)(encoder_last_c)

    # Decoder LSTM
    decoder_input = RepeatVector(output_train.shape[1])(encoder_last_h)

    decoder_stack_h = LSTM(n_hidden, activation='elu', dropout=0.2, recurrent_dropout=0.2,
    return_state=False, return_sequences=True)(
    decoder_input, initial_state=[encoder_last_h, encoder_last_c])

    # Attention layer
    attention = dot([decoder_stack_h, encoder_stack_h], axes=[2, 2])
    attention = Activation('softmax')(attention)

    # Calculate context vector with batch normalisation
    context = dot([attention, encoder_stack_h], axes=[2,1])
    context = BatchNormalization(momentum=0.6)(context)

    # Combine context vector with stacked hidden states of decoder for input to the last dense layer
    decoder_combined_context = concatenate([context, decoder_stack_h])

    # Dense layer with repeated weights
    out = TimeDistributed(Dense(output_train.shape[2]))(decoder_combined_context)

    # Compile model
    model = Model(inputs=input_train, outputs=out)
    opt = Adam(learning_rate=0.001, clipnorm=1)
    model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mae'])
    print(model)

    return model

# %%
# Fit model
def fit_model(model, samples):
    epc = 500
    es = EarlyStopping(monitor='val_loss', mode='min', patience=50, restore_best_weights=True)
    history = model.fit(samples["X_input_train"], samples["y_output_train"],  validation_data=(samples["X_input_vali"],samples["y_output_vali"]), 
                        epochs=epc, verbose=1, callbacks=[es], 
                        batch_size=64, shuffle=False)

    return model, history

# %%
# Execute over all conditions for n trials
samples_all = {}
model_all = {}
history_all = {}
results_all = {}
data_all = {}
for x in trial: data_all[x] = {} # prepare nested dictionary

# iterate over trials
for j in range(len(trial)):
    # set random number generator for each trial
    os.environ['PYTHONHASHSEED']=str(j)
    random.seed(j)
    np.random.seed(j)
    tensorflow.random.set_seed(j)
    # iterate over conditions
    for i in range(len(condition)):
        samples = sample_preperation(condition[i])
        samples_all[condition[i]] = samples
        model = lstm_decoder_encoder(samples) # use lstm_decoder_encoder_luong_attention() for model with attention
        model, history = fit_model(model, samples)
        model_path = f"model/model_{trial[j]}_{condition[i]}.h5"
        model_all[condition[i]] = model_path # models aren't pickable in tensorflow < 2.7 and can't be imported via pickle
        model.save(model_path) # -> using model.save() instead
        history_all[condition[i]] = history.history
        results = model.evaluate(samples["X_input_test"], samples["y_output_test"], batch_size=64)
        results_all[condition[i]] = results
    # deepcopy to prevent reusing the same dictionary
    samples_all_copy = deepcopy(samples_all)
    model_all_copy = deepcopy(model_all)
    history_all_copy = deepcopy(history_all)
    results_all_copy = deepcopy(results_all)
    # create nested dictionary for everything
    data_all[trial[j]]["samples_all"] = samples_all_copy
    data_all[trial[j]]["model_all"] = model_all_copy
    data_all[trial[j]]["history_all"] = history_all_copy
    data_all[trial[j]]["results_all"] = results_all_copy
# Out:
# Loaded data with shape (4, 14800) and type float32
# Number of dyads: 2
# num_train_samples per dyad: 174
# num_val_samples per dyad: 58
# num_test_samples per dyad: 58
# Length of samples for each set: 348 116 116
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_19 (InputLayer)          [(None, 250, 2)]     0           []
#
#  lstm_18 (LSTM)                 [(None, 100),        41200       ['input_19[0][0]']
#                                  (None, 100),
#                                  (None, 100)]
#
#  batch_normalization_18 (BatchN  (None, 100)         400         ['lstm_18[0][0]']
#  ormalization)
#
#  repeat_vector_9 (RepeatVector)  (None, 100, 100)    0           ['batch_normalization_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 100)         400         ['lstm_18[0][2]']
#  ormalization)
#
#  lstm_19 (LSTM)                 (None, 100, 100)     80400       ['repeat_vector_9[0][0]',
#                                                                   'batch_normalization_18[0][0]',
#                                                                   'batch_normalization_19[0][0]']
#
#  time_distributed_9 (TimeDistri  (None, 100, 2)      202         ['lstm_19[0][0]']
#  buted)
#
# ==================================================================================================
# Total params: 122,602
# Trainable params: 122,202
# Non-trainable params: 400
# __________________________________________________________________________________________________
# <keras.engine.functional.Functional object at 0x7f08d812fdd0>
# Epoch 1/500
# 6/6 [==============================] - 10s 907ms/step - loss: 0.2575 - mae: 0.4038 - val_loss: 0.1267 - val_mae: 0.3193
# Epoch 2/500
# 6/6 [==============================] - 4s 720ms/step - loss: 0.1545 - mae: 0.3359 - val_loss: 0.1268 - val_mae: 0.3176
# Epoch 3/500
# 6/6 [==============================] - 4s 760ms/step - loss: 0.1386 - mae: 0.3241 - val_loss: 0.1266 - val_mae: 0.3142
# Epoch 4/500
# 6/6 [==============================] - 4s 737ms/step - loss: 0.1319 - mae: 0.3174 - val_loss: 0.1218 - val_mae: 0.3101
# Epoch 5/500
# 6/6 [==============================] - 4s 743ms/step - loss: 0.1290 - mae: 0.3141 - val_loss: 0.1203 - val_mae: 0.3072
# Epoch 6/500
# 6/6 [==============================] - 4s 740ms/step - loss: 0.1266 - mae: 0.3116 - val_loss: 0.1188 - val_mae: 0.3047
# Epoch 7/500
# 6/6 [==============================] - 5s 753ms/step - loss: 0.1239 - mae: 0.3083 - val_loss: 0.1159 - val_mae: 0.3009
# Epoch 8/500
# 6/6 [==============================] - 4s 708ms/step - loss: 0.1220 - mae: 0.3065 - val_loss: 0.1148 - val_mae: 0.2994
# Epoch 9/500
# 6/6 [==============================] - 4s 726ms/step - loss: 0.1201 - mae: 0.3039 - val_loss: 0.1143 - val_mae: 0.2980
# Epoch 10/500
# 6/6 [==============================] - 5s 770ms/step - loss: 0.1203 - mae: 0.3037 - val_loss: 0.1138 - val_mae: 0.2970
# Epoch 11/500
# 6/6 [==============================] - 4s 719ms/step - loss: 0.1196 - mae: 0.3026 - val_loss: 0.1122 - val_mae: 0.2946
# Epoch 12/500
# 6/6 [==============================] - 4s 723ms/step - loss: 0.1175 - mae: 0.2993 - val_loss: 0.1117 - val_mae: 0.2931
# Epoch 13/500
# 6/6 [==============================] - 5s 748ms/step - loss: 0.1164 - mae: 0.2976 - val_loss: 0.1095 - val_mae: 0.2899
# Epoch 14/500
# 6/6 [==============================] - 4s 745ms/step - loss: 0.1156 - mae: 0.2962 - val_loss: 0.1085 - val_mae: 0.2881
# Epoch 15/500
# 6/6 [==============================] - 4s 724ms/step - loss: 0.1143 - mae: 0.2946 - val_loss: 0.1081 - val_mae: 0.2866
# Epoch 16/500
# 6/6 [==============================] - 4s 739ms/step - loss: 0.1136 - mae: 0.2930 - val_loss: 0.1071 - val_mae: 0.2842
# Epoch 17/500
# 6/6 [==============================] - 4s 746ms/step - loss: 0.1117 - mae: 0.2903 - val_loss: 0.1056 - val_mae: 0.2817
# Epoch 18/500
# 6/6 [==============================] - 4s 715ms/step - loss: 0.1113 - mae: 0.2892 - val_loss: 0.1053 - val_mae: 0.2805
# Epoch 19/500
# 6/6 [==============================] - 4s 749ms/step - loss: 0.1099 - mae: 0.2869 - val_loss: 0.1051 - val_mae: 0.2791
# Epoch 20/500
# 6/6 [==============================] - 4s 720ms/step - loss: 0.1096 - mae: 0.2855 - val_loss: 0.1052 - val_mae: 0.2786
# Epoch 21/500
# 6/6 [==============================] - 4s 710ms/step - loss: 0.1093 - mae: 0.2850 - val_loss: 0.1028 - val_mae: 0.2741
# Epoch 22/500
# 6/6 [==============================] - 4s 713ms/step - loss: 0.1072 - mae: 0.2810 - val_loss: 0.1013 - val_mae: 0.2714
# Epoch 23/500
# 6/6 [==============================] - 4s 722ms/step - loss: 0.1063 - mae: 0.2804 - val_loss: 0.0986 - val_mae: 0.2669
# Epoch 24/500
# 6/6 [==============================] - 5s 754ms/step - loss: 0.1056 - mae: 0.2777 - val_loss: 0.1010 - val_mae: 0.2729
# Epoch 25/500
# 6/6 [==============================] - 4s 723ms/step - loss: 0.1063 - mae: 0.2809 - val_loss: 0.0996 - val_mae: 0.2700
# Epoch 26/500
# 6/6 [==============================] - 4s 723ms/step - loss: 0.1040 - mae: 0.2771 - val_loss: 0.0949 - val_mae: 0.2606
# Epoch 27/500
# 6/6 [==============================] - 4s 711ms/step - loss: 0.1007 - mae: 0.2704 - val_loss: 0.0923 - val_mae: 0.2545
# Epoch 28/500
# 6/6 [==============================] - 4s 750ms/step - loss: 0.0982 - mae: 0.2660 - val_loss: 0.0907 - val_mae: 0.2514
# Epoch 29/500
# 6/6 [==============================] - 4s 738ms/step - loss: 0.0958 - mae: 0.2607 - val_loss: 0.0864 - val_mae: 0.2416
# Epoch 30/500
# 6/6 [==============================] - 4s 721ms/step - loss: 0.0921 - mae: 0.2545 - val_loss: 0.0845 - val_mae: 0.2372
# Epoch 31/500
# 6/6 [==============================] - 4s 738ms/step - loss: 0.0878 - mae: 0.2474 - val_loss: 0.0765 - val_mae: 0.2244
# Epoch 32/500
# 6/6 [==============================] - 4s 725ms/step - loss: 0.0847 - mae: 0.2392 - val_loss: 0.0696 - val_mae: 0.2116
# Epoch 33/500
# 6/6 [==============================] - 4s 707ms/step - loss: 0.0802 - mae: 0.2305 - val_loss: 0.0650 - val_mae: 0.2023
# Epoch 34/500
# 6/6 [==============================] - 4s 733ms/step - loss: 0.0768 - mae: 0.2247 - val_loss: 0.0693 - val_mae: 0.2095
# Epoch 35/500
# 6/6 [==============================] - 4s 718ms/step - loss: 0.0756 - mae: 0.2227 - val_loss: 0.0695 - val_mae: 0.2105
# Epoch 36/500
# 6/6 [==============================] - 4s 743ms/step - loss: 0.0730 - mae: 0.2171 - val_loss: 0.0599 - val_mae: 0.1886
# Epoch 37/500
# 6/6 [==============================] - 4s 715ms/step - loss: 0.0700 - mae: 0.2101 - val_loss: 0.0542 - val_mae: 0.1776
# Epoch 38/500
# 6/6 [==============================] - 4s 731ms/step - loss: 0.0718 - mae: 0.2142 - val_loss: 0.0668 - val_mae: 0.2058
# Epoch 39/500
# 6/6 [==============================] - 4s 732ms/step - loss: 0.0701 - mae: 0.2141 - val_loss: 0.0580 - val_mae: 0.1845
# Epoch 40/500
# 6/6 [==============================] - 4s 743ms/step - loss: 0.0645 - mae: 0.2012 - val_loss: 0.0528 - val_mae: 0.1742
# Epoch 41/500
# 6/6 [==============================] - 4s 725ms/step - loss: 0.0640 - mae: 0.1974 - val_loss: 0.0565 - val_mae: 0.1820
# Epoch 42/500
# 6/6 [==============================] - 4s 725ms/step - loss: 0.0662 - mae: 0.2038 - val_loss: 0.0580 - val_mae: 0.1872
# Epoch 43/500
# 6/6 [==============================] - 4s 724ms/step - loss: 0.0620 - mae: 0.1958 - val_loss: 0.0464 - val_mae: 0.1609
# Epoch 44/500
# 6/6 [==============================] - 4s 744ms/step - loss: 0.0638 - mae: 0.1965 - val_loss: 0.0578 - val_mae: 0.1842
# Epoch 45/500
# 6/6 [==============================] - 4s 710ms/step - loss: 0.0611 - mae: 0.1952 - val_loss: 0.0523 - val_mae: 0.1717
# Epoch 46/500
# 6/6 [==============================] - 4s 720ms/step - loss: 0.0605 - mae: 0.1916 - val_loss: 0.0481 - val_mae: 0.1630
# Epoch 47/500
# 6/6 [==============================] - 4s 746ms/step - loss: 0.0592 - mae: 0.1890 - val_loss: 0.0535 - val_mae: 0.1759
# Epoch 48/500
# 6/6 [==============================] - 4s 718ms/step - loss: 0.0592 - mae: 0.1902 - val_loss: 0.0498 - val_mae: 0.1673
# Epoch 49/500
# 6/6 [==============================] - 5s 772ms/step - loss: 0.0576 - mae: 0.1856 - val_loss: 0.0491 - val_mae: 0.1656
# Epoch 50/500
# 6/6 [==============================] - 4s 744ms/step - loss: 0.0574 - mae: 0.1854 - val_loss: 0.0484 - val_mae: 0.1626
# Epoch 51/500
# 6/6 [==============================] - 4s 739ms/step - loss: 0.0567 - mae: 0.1833 - val_loss: 0.0475 - val_mae: 0.1617
# Epoch 52/500
# 6/6 [==============================] - 4s 726ms/step - loss: 0.0578 - mae: 0.1860 - val_loss: 0.0496 - val_mae: 0.1668
# Epoch 53/500
# 6/6 [==============================] - 4s 741ms/step - loss: 0.0574 - mae: 0.1851 - val_loss: 0.0515 - val_mae: 0.1707
# Epoch 54/500
# 6/6 [==============================] - 5s 767ms/step - loss: 0.0566 - mae: 0.1845 - val_loss: 0.0475 - val_mae: 0.1629
# Epoch 55/500
# 6/6 [==============================] - 4s 713ms/step - loss: 0.0574 - mae: 0.1844 - val_loss: 0.0469 - val_mae: 0.1610
# Epoch 56/500
# 6/6 [==============================] - 4s 721ms/step - loss: 0.0565 - mae: 0.1832 - val_loss: 0.0502 - val_mae: 0.1673
# Epoch 57/500
# 6/6 [==============================] - 4s 729ms/step - loss: 0.0589 - mae: 0.1877 - val_loss: 0.0465 - val_mae: 0.1601
# Epoch 58/500
# 6/6 [==============================] - 5s 767ms/step - loss: 0.0571 - mae: 0.1846 - val_loss: 0.0477 - val_mae: 0.1640
# Epoch 59/500
# 6/6 [==============================] - 4s 758ms/step - loss: 0.0564 - mae: 0.1825 - val_loss: 0.0491 - val_mae: 0.1662
# Epoch 60/500
# 6/6 [==============================] - 4s 745ms/step - loss: 0.0568 - mae: 0.1828 - val_loss: 0.0478 - val_mae: 0.1634
# Epoch 61/500
# 6/6 [==============================] - 4s 710ms/step - loss: 0.0553 - mae: 0.1807 - val_loss: 0.0474 - val_mae: 0.1617
# Epoch 62/500
# 6/6 [==============================] - 4s 730ms/step - loss: 0.0546 - mae: 0.1804 - val_loss: 0.0491 - val_mae: 0.1659
# Epoch 63/500
# 6/6 [==============================] - 4s 711ms/step - loss: 0.0554 - mae: 0.1811 - val_loss: 0.0455 - val_mae: 0.1574
# Epoch 64/500
# 6/6 [==============================] - 4s 708ms/step - loss: 0.0549 - mae: 0.1798 - val_loss: 0.0486 - val_mae: 0.1643
# Epoch 65/500
# 6/6 [==============================] - 4s 717ms/step - loss: 0.0549 - mae: 0.1806 - val_loss: 0.0485 - val_mae: 0.1634
# Epoch 66/500
# 6/6 [==============================] - 4s 705ms/step - loss: 0.0550 - mae: 0.1800 - val_loss: 0.0460 - val_mae: 0.1601
# Epoch 67/500
# 6/6 [==============================] - 5s 770ms/step - loss: 0.0543 - mae: 0.1797 - val_loss: 0.0471 - val_mae: 0.1619
# Epoch 68/500
# 6/6 [==============================] - 4s 723ms/step - loss: 0.0541 - mae: 0.1788 - val_loss: 0.0486 - val_mae: 0.1646
# Epoch 69/500
# 6/6 [==============================] - 4s 736ms/step - loss: 0.0538 - mae: 0.1769 - val_loss: 0.0452 - val_mae: 0.1553
# Epoch 70/500
# 6/6 [==============================] - 4s 751ms/step - loss: 0.0565 - mae: 0.1815 - val_loss: 0.0486 - val_mae: 0.1649
# Epoch 71/500
# 6/6 [==============================] - 4s 750ms/step - loss: 0.0535 - mae: 0.1779 - val_loss: 0.0482 - val_mae: 0.1632
# Epoch 72/500
# 6/6 [==============================] - 4s 740ms/step - loss: 0.0536 - mae: 0.1768 - val_loss: 0.0439 - val_mae: 0.1527
# Epoch 73/500
# 6/6 [==============================] - 4s 707ms/step - loss: 0.0523 - mae: 0.1744 - val_loss: 0.0471 - val_mae: 0.1622
# Epoch 74/500
# 6/6 [==============================] - 4s 726ms/step - loss: 0.0539 - mae: 0.1776 - val_loss: 0.0505 - val_mae: 0.1673
# Epoch 75/500
# 6/6 [==============================] - 4s 741ms/step - loss: 0.0542 - mae: 0.1784 - val_loss: 0.0436 - val_mae: 0.1518
# Epoch 76/500
# 6/6 [==============================] - 4s 725ms/step - loss: 0.0522 - mae: 0.1739 - val_loss: 0.0498 - val_mae: 0.1674
# Epoch 77/500
# 6/6 [==============================] - 5s 757ms/step - loss: 0.0541 - mae: 0.1779 - val_loss: 0.0453 - val_mae: 0.1577
# Epoch 78/500
# 6/6 [==============================] - 4s 741ms/step - loss: 0.0520 - mae: 0.1727 - val_loss: 0.0439 - val_mae: 0.1521
# Epoch 79/500
# 6/6 [==============================] - 4s 719ms/step - loss: 0.0529 - mae: 0.1746 - val_loss: 0.0487 - val_mae: 0.1649
# Epoch 80/500
# 6/6 [==============================] - 5s 761ms/step - loss: 0.0532 - mae: 0.1763 - val_loss: 0.0437 - val_mae: 0.1537
# Epoch 81/500
# 6/6 [==============================] - 4s 745ms/step - loss: 0.0514 - mae: 0.1726 - val_loss: 0.0450 - val_mae: 0.1551
# Epoch 82/500
# 6/6 [==============================] - 4s 733ms/step - loss: 0.0516 - mae: 0.1720 - val_loss: 0.0450 - val_mae: 0.1568
# Epoch 83/500
# 6/6 [==============================] - 4s 722ms/step - loss: 0.0537 - mae: 0.1771 - val_loss: 0.0505 - val_mae: 0.1678
# Epoch 84/500
# 6/6 [==============================] - 4s 757ms/step - loss: 0.0522 - mae: 0.1738 - val_loss: 0.0444 - val_mae: 0.1551
# Epoch 85/500
# 6/6 [==============================] - 4s 735ms/step - loss: 0.0519 - mae: 0.1734 - val_loss: 0.0430 - val_mae: 0.1505
# Epoch 86/500
# 6/6 [==============================] - 4s 737ms/step - loss: 0.0507 - mae: 0.1715 - val_loss: 0.0484 - val_mae: 0.1643
# Epoch 87/500
# 6/6 [==============================] - 4s 723ms/step - loss: 0.0504 - mae: 0.1714 - val_loss: 0.0414 - val_mae: 0.1465
# Epoch 88/500
# 6/6 [==============================] - 4s 748ms/step - loss: 0.0516 - mae: 0.1707 - val_loss: 0.0462 - val_mae: 0.1586
# Epoch 89/500
# 6/6 [==============================] - 4s 720ms/step - loss: 0.0523 - mae: 0.1748 - val_loss: 0.0462 - val_mae: 0.1597
# Epoch 90/500
# 6/6 [==============================] - 4s 729ms/step - loss: 0.0533 - mae: 0.1762 - val_loss: 0.0464 - val_mae: 0.1598
# Epoch 91/500
# 6/6 [==============================] - 4s 745ms/step - loss: 0.0514 - mae: 0.1721 - val_loss: 0.0467 - val_mae: 0.1602
# Epoch 92/500
# 6/6 [==============================] - 4s 736ms/step - loss: 0.0523 - mae: 0.1752 - val_loss: 0.0443 - val_mae: 0.1553
# Epoch 93/500
# 6/6 [==============================] - 4s 723ms/step - loss: 0.0515 - mae: 0.1735 - val_loss: 0.0471 - val_mae: 0.1605
# Epoch 94/500
# 6/6 [==============================] - 4s 719ms/step - loss: 0.0516 - mae: 0.1738 - val_loss: 0.0455 - val_mae: 0.1581
# Epoch 95/500
# 6/6 [==============================] - 4s 704ms/step - loss: 0.0512 - mae: 0.1719 - val_loss: 0.0427 - val_mae: 0.1503
# Epoch 96/500
# 6/6 [==============================] - 4s 722ms/step - loss: 0.0503 - mae: 0.1697 - val_loss: 0.0456 - val_mae: 0.1564
# Epoch 97/500
# 6/6 [==============================] - 4s 712ms/step - loss: 0.0515 - mae: 0.1721 - val_loss: 0.0502 - val_mae: 0.1675
# Epoch 98/500
# 6/6 [==============================] - 4s 732ms/step - loss: 0.0503 - mae: 0.1710 - val_loss: 0.0418 - val_mae: 0.1501
# Epoch 99/500
# 6/6 [==============================] - 4s 709ms/step - loss: 0.0506 - mae: 0.1697 - val_loss: 0.0449 - val_mae: 0.1564
# Epoch 100/500
# 6/6 [==============================] - 4s 742ms/step - loss: 0.0517 - mae: 0.1711 - val_loss: 0.0488 - val_mae: 0.1653
# Epoch 101/500
# 6/6 [==============================] - 4s 735ms/step - loss: 0.0518 - mae: 0.1736 - val_loss: 0.0469 - val_mae: 0.1615
# Epoch 102/500
# 6/6 [==============================] - 4s 740ms/step - loss: 0.0510 - mae: 0.1712 - val_loss: 0.0465 - val_mae: 0.1580
# Epoch 103/500
# 6/6 [==============================] - 4s 734ms/step - loss: 0.0498 - mae: 0.1687 - val_loss: 0.0442 - val_mae: 0.1548
# Epoch 104/500
# 6/6 [==============================] - 4s 732ms/step - loss: 0.0497 - mae: 0.1690 - val_loss: 0.0431 - val_mae: 0.1516
# Epoch 105/500
# 6/6 [==============================] - 4s 759ms/step - loss: 0.0506 - mae: 0.1697 - val_loss: 0.0470 - val_mae: 0.1586
# Epoch 106/500
# 6/6 [==============================] - 4s 720ms/step - loss: 0.0513 - mae: 0.1712 - val_loss: 0.0474 - val_mae: 0.1624
# Epoch 107/500
# 6/6 [==============================] - 4s 755ms/step - loss: 0.0511 - mae: 0.1727 - val_loss: 0.0417 - val_mae: 0.1496
# Epoch 108/500
# 6/6 [==============================] - 4s 737ms/step - loss: 0.0507 - mae: 0.1699 - val_loss: 0.0454 - val_mae: 0.1572
# Epoch 109/500
# 6/6 [==============================] - 4s 711ms/step - loss: 0.0516 - mae: 0.1724 - val_loss: 0.0436 - val_mae: 0.1548
# Epoch 110/500
# 6/6 [==============================] - 4s 712ms/step - loss: 0.0500 - mae: 0.1699 - val_loss: 0.0425 - val_mae: 0.1514
# Epoch 111/500
# 6/6 [==============================] - 4s 745ms/step - loss: 0.0497 - mae: 0.1679 - val_loss: 0.0459 - val_mae: 0.1572
# Epoch 112/500
# 6/6 [==============================] - 4s 744ms/step - loss: 0.0503 - mae: 0.1699 - val_loss: 0.0421 - val_mae: 0.1495
# Epoch 113/500
# 6/6 [==============================] - 4s 711ms/step - loss: 0.0491 - mae: 0.1675 - val_loss: 0.0450 - val_mae: 0.1563
# Epoch 114/500
# 6/6 [==============================] - 4s 731ms/step - loss: 0.0499 - mae: 0.1684 - val_loss: 0.0476 - val_mae: 0.1623
# Epoch 115/500
# 6/6 [==============================] - 4s 742ms/step - loss: 0.0498 - mae: 0.1700 - val_loss: 0.0419 - val_mae: 0.1477
# Epoch 116/500
# 6/6 [==============================] - 4s 738ms/step - loss: 0.0494 - mae: 0.1671 - val_loss: 0.0421 - val_mae: 0.1492
# Epoch 117/500
# 6/6 [==============================] - 4s 711ms/step - loss: 0.0496 - mae: 0.1673 - val_loss: 0.0450 - val_mae: 0.1579
# Epoch 118/500
# 6/6 [==============================] - 4s 737ms/step - loss: 0.0504 - mae: 0.1709 - val_loss: 0.0468 - val_mae: 0.1592
# Epoch 119/500
# 6/6 [==============================] - 4s 739ms/step - loss: 0.0501 - mae: 0.1690 - val_loss: 0.0430 - val_mae: 0.1543
# Epoch 120/500
# 6/6 [==============================] - 4s 751ms/step - loss: 0.0494 - mae: 0.1692 - val_loss: 0.0449 - val_mae: 0.1548
# Epoch 121/500
# 6/6 [==============================] - 5s 758ms/step - loss: 0.0488 - mae: 0.1665 - val_loss: 0.0444 - val_mae: 0.1535
# Epoch 122/500
# 6/6 [==============================] - 4s 724ms/step - loss: 0.0472 - mae: 0.1636 - val_loss: 0.0410 - val_mae: 0.1471
# Epoch 123/500
# 6/6 [==============================] - 4s 705ms/step - loss: 0.0507 - mae: 0.1701 - val_loss: 0.0426 - val_mae: 0.1501
# Epoch 124/500
# 6/6 [==============================] - 4s 747ms/step - loss: 0.0483 - mae: 0.1661 - val_loss: 0.0427 - val_mae: 0.1516
# Epoch 125/500
# 6/6 [==============================] - 4s 718ms/step - loss: 0.0493 - mae: 0.1692 - val_loss: 0.0414 - val_mae: 0.1478
# Epoch 126/500
# 6/6 [==============================] - 4s 735ms/step - loss: 0.0472 - mae: 0.1632 - val_loss: 0.0422 - val_mae: 0.1512
# Epoch 127/500
# 6/6 [==============================] - 4s 718ms/step - loss: 0.0485 - mae: 0.1677 - val_loss: 0.0435 - val_mae: 0.1523
# Epoch 128/500
# 6/6 [==============================] - 4s 716ms/step - loss: 0.0498 - mae: 0.1682 - val_loss: 0.0411 - val_mae: 0.1496
# Epoch 129/500
# 6/6 [==============================] - 4s 723ms/step - loss: 0.0479 - mae: 0.1652 - val_loss: 0.0414 - val_mae: 0.1507
# Epoch 130/500
# 6/6 [==============================] - 4s 738ms/step - loss: 0.0461 - mae: 0.1609 - val_loss: 0.0418 - val_mae: 0.1514
# Epoch 131/500
# 6/6 [==============================] - 4s 726ms/step - loss: 0.0452 - mae: 0.1613 - val_loss: 0.0396 - val_mae: 0.1447
# Epoch 132/500
# 6/6 [==============================] - 4s 729ms/step - loss: 0.0464 - mae: 0.1613 - val_loss: 0.0419 - val_mae: 0.1521
# Epoch 133/500
# 6/6 [==============================] - 5s 769ms/step - loss: 0.0468 - mae: 0.1622 - val_loss: 0.0402 - val_mae: 0.1489
# Epoch 134/500
# 6/6 [==============================] - 4s 743ms/step - loss: 0.0454 - mae: 0.1616 - val_loss: 0.0420 - val_mae: 0.1484
# Epoch 135/500
# 6/6 [==============================] - 4s 724ms/step - loss: 0.0477 - mae: 0.1629 - val_loss: 0.0418 - val_mae: 0.1492
# Epoch 136/500
# 6/6 [==============================] - 4s 727ms/step - loss: 0.0476 - mae: 0.1652 - val_loss: 0.0418 - val_mae: 0.1507
# Epoch 137/500
# 6/6 [==============================] - 4s 723ms/step - loss: 0.0478 - mae: 0.1660 - val_loss: 0.0393 - val_mae: 0.1461
# Epoch 138/500
# 6/6 [==============================] - 4s 748ms/step - loss: 0.0464 - mae: 0.1623 - val_loss: 0.0371 - val_mae: 0.1409
# Epoch 139/500
# 6/6 [==============================] - 4s 747ms/step - loss: 0.0472 - mae: 0.1633 - val_loss: 0.0451 - val_mae: 0.1577
# Epoch 140/500
# 6/6 [==============================] - 4s 710ms/step - loss: 0.0445 - mae: 0.1587 - val_loss: 0.0378 - val_mae: 0.1402
# Epoch 141/500
# 6/6 [==============================] - 5s 765ms/step - loss: 0.0441 - mae: 0.1585 - val_loss: 0.0354 - val_mae: 0.1367
# Epoch 142/500
# 6/6 [==============================] - 4s 710ms/step - loss: 0.0467 - mae: 0.1629 - val_loss: 0.0481 - val_mae: 0.1634
# Epoch 143/500
# 6/6 [==============================] - 4s 719ms/step - loss: 0.0441 - mae: 0.1594 - val_loss: 0.0363 - val_mae: 0.1370
# Epoch 144/500
# 6/6 [==============================] - 4s 733ms/step - loss: 0.0470 - mae: 0.1635 - val_loss: 0.0356 - val_mae: 0.1386
# Epoch 145/500
# 6/6 [==============================] - 4s 725ms/step - loss: 0.0442 - mae: 0.1583 - val_loss: 0.0425 - val_mae: 0.1505
# Epoch 146/500
# 6/6 [==============================] - 4s 742ms/step - loss: 0.0453 - mae: 0.1604 - val_loss: 0.0391 - val_mae: 0.1435
# Epoch 147/500
# 6/6 [==============================] - 4s 708ms/step - loss: 0.0447 - mae: 0.1595 - val_loss: 0.0369 - val_mae: 0.1403
# Epoch 148/500
# 6/6 [==============================] - 4s 752ms/step - loss: 0.0443 - mae: 0.1590 - val_loss: 0.0400 - val_mae: 0.1435
# Epoch 149/500
# 6/6 [==============================] - 4s 729ms/step - loss: 0.0442 - mae: 0.1580 - val_loss: 0.0374 - val_mae: 0.1424
# Epoch 150/500
# 6/6 [==============================] - 4s 751ms/step - loss: 0.0449 - mae: 0.1595 - val_loss: 0.0402 - val_mae: 0.1455
# Epoch 151/500
# 6/6 [==============================] - 4s 727ms/step - loss: 0.0448 - mae: 0.1596 - val_loss: 0.0354 - val_mae: 0.1380
# Epoch 152/500
# 6/6 [==============================] - 4s 727ms/step - loss: 0.0470 - mae: 0.1639 - val_loss: 0.0422 - val_mae: 0.1508
# Epoch 153/500
# 6/6 [==============================] - 4s 721ms/step - loss: 0.0461 - mae: 0.1619 - val_loss: 0.0393 - val_mae: 0.1465
# Epoch 154/500
# 6/6 [==============================] - 4s 726ms/step - loss: 0.0442 - mae: 0.1586 - val_loss: 0.0378 - val_mae: 0.1413
# Epoch 155/500
# 6/6 [==============================] - 5s 748ms/step - loss: 0.0449 - mae: 0.1607 - val_loss: 0.0370 - val_mae: 0.1411
# Epoch 156/500
# 6/6 [==============================] - 4s 736ms/step - loss: 0.0439 - mae: 0.1568 - val_loss: 0.0403 - val_mae: 0.1451
# Epoch 157/500
# 6/6 [==============================] - 4s 720ms/step - loss: 0.0440 - mae: 0.1577 - val_loss: 0.0366 - val_mae: 0.1371
# Epoch 158/500
# 6/6 [==============================] - 4s 720ms/step - loss: 0.0433 - mae: 0.1572 - val_loss: 0.0339 - val_mae: 0.1353
# Epoch 159/500
# 6/6 [==============================] - 4s 736ms/step - loss: 0.0427 - mae: 0.1547 - val_loss: 0.0381 - val_mae: 0.1433
# Epoch 160/500
# 6/6 [==============================] - 4s 736ms/step - loss: 0.0421 - mae: 0.1548 - val_loss: 0.0355 - val_mae: 0.1364
# Epoch 161/500
# 6/6 [==============================] - 4s 761ms/step - loss: 0.0425 - mae: 0.1539 - val_loss: 0.0408 - val_mae: 0.1471
# Epoch 162/500
# 6/6 [==============================] - 5s 755ms/step - loss: 0.0426 - mae: 0.1545 - val_loss: 0.0390 - val_mae: 0.1435
# Epoch 163/500
# 6/6 [==============================] - 4s 726ms/step - loss: 0.0462 - mae: 0.1622 - val_loss: 0.0383 - val_mae: 0.1434
# Epoch 164/500
# 6/6 [==============================] - 4s 717ms/step - loss: 0.0443 - mae: 0.1565 - val_loss: 0.0364 - val_mae: 0.1409
# Epoch 165/500
# 6/6 [==============================] - 4s 705ms/step - loss: 0.0420 - mae: 0.1548 - val_loss: 0.0423 - val_mae: 0.1510
# Epoch 166/500
# 6/6 [==============================] - 4s 721ms/step - loss: 0.0419 - mae: 0.1536 - val_loss: 0.0322 - val_mae: 0.1286
# Epoch 167/500
# 6/6 [==============================] - 4s 728ms/step - loss: 0.0436 - mae: 0.1567 - val_loss: 0.0397 - val_mae: 0.1456
# Epoch 168/500
# 6/6 [==============================] - 4s 719ms/step - loss: 0.0417 - mae: 0.1530 - val_loss: 0.0397 - val_mae: 0.1460
# Epoch 169/500
# 6/6 [==============================] - 4s 755ms/step - loss: 0.0408 - mae: 0.1527 - val_loss: 0.0362 - val_mae: 0.1369
# Epoch 170/500
# 6/6 [==============================] - 5s 760ms/step - loss: 0.0444 - mae: 0.1586 - val_loss: 0.0344 - val_mae: 0.1354
# Epoch 171/500
# 6/6 [==============================] - 4s 739ms/step - loss: 0.0430 - mae: 0.1553 - val_loss: 0.0402 - val_mae: 0.1453
# Epoch 172/500
# 6/6 [==============================] - 4s 732ms/step - loss: 0.0406 - mae: 0.1518 - val_loss: 0.0367 - val_mae: 0.1398
# Epoch 173/500
# 6/6 [==============================] - 4s 716ms/step - loss: 0.0401 - mae: 0.1503 - val_loss: 0.0339 - val_mae: 0.1297
# Epoch 174/500
# 6/6 [==============================] - 4s 732ms/step - loss: 0.0441 - mae: 0.1574 - val_loss: 0.0410 - val_mae: 0.1494
# Epoch 175/500
# 6/6 [==============================] - 5s 769ms/step - loss: 0.0435 - mae: 0.1582 - val_loss: 0.0406 - val_mae: 0.1469
# Epoch 176/500
# 6/6 [==============================] - 5s 743ms/step - loss: 0.0420 - mae: 0.1533 - val_loss: 0.0345 - val_mae: 0.1354
# Epoch 177/500
# 6/6 [==============================] - 4s 715ms/step - loss: 0.0440 - mae: 0.1581 - val_loss: 0.0423 - val_mae: 0.1526
# Epoch 178/500
# 6/6 [==============================] - 4s 712ms/step - loss: 0.0424 - mae: 0.1547 - val_loss: 0.0439 - val_mae: 0.1530
# Epoch 179/500
# 6/6 [==============================] - 4s 726ms/step - loss: 0.0428 - mae: 0.1562 - val_loss: 0.0348 - val_mae: 0.1354
# Epoch 180/500
# 6/6 [==============================] - 4s 732ms/step - loss: 0.0408 - mae: 0.1519 - val_loss: 0.0390 - val_mae: 0.1402
# Epoch 181/500
# 6/6 [==============================] - 4s 730ms/step - loss: 0.0427 - mae: 0.1534 - val_loss: 0.0321 - val_mae: 0.1296
# Epoch 182/500
# 6/6 [==============================] - 4s 752ms/step - loss: 0.0399 - mae: 0.1511 - val_loss: 0.0393 - val_mae: 0.1445
# Epoch 183/500
# 6/6 [==============================] - 5s 770ms/step - loss: 0.0392 - mae: 0.1484 - val_loss: 0.0348 - val_mae: 0.1339
# Epoch 184/500
# 6/6 [==============================] - 5s 762ms/step - loss: 0.0375 - mae: 0.1442 - val_loss: 0.0371 - val_mae: 0.1392
# Epoch 185/500
# 6/6 [==============================] - 4s 724ms/step - loss: 0.0370 - mae: 0.1440 - val_loss: 0.0349 - val_mae: 0.1351
# Epoch 186/500
# 6/6 [==============================] - 4s 727ms/step - loss: 0.0369 - mae: 0.1440 - val_loss: 0.0358 - val_mae: 0.1357
# Epoch 187/500
# 6/6 [==============================] - 4s 716ms/step - loss: 0.0384 - mae: 0.1467 - val_loss: 0.0337 - val_mae: 0.1303
# Epoch 188/500
# 6/6 [==============================] - 4s 754ms/step - loss: 0.0373 - mae: 0.1433 - val_loss: 0.0372 - val_mae: 0.1386
# Epoch 189/500
# 6/6 [==============================] - 4s 724ms/step - loss: 0.0384 - mae: 0.1449 - val_loss: 0.0386 - val_mae: 0.1409
# Epoch 190/500
# 6/6 [==============================] - 4s 753ms/step - loss: 0.0396 - mae: 0.1500 - val_loss: 0.0361 - val_mae: 0.1397
# Epoch 191/500
# 6/6 [==============================] - 4s 719ms/step - loss: 0.0374 - mae: 0.1450 - val_loss: 0.0375 - val_mae: 0.1384
# Epoch 192/500
# 6/6 [==============================] - 4s 743ms/step - loss: 0.0394 - mae: 0.1473 - val_loss: 0.0340 - val_mae: 0.1341
# Epoch 193/500
# 6/6 [==============================] - 4s 713ms/step - loss: 0.0397 - mae: 0.1500 - val_loss: 0.0330 - val_mae: 0.1300
# Epoch 194/500
# 6/6 [==============================] - 4s 733ms/step - loss: 0.0370 - mae: 0.1434 - val_loss: 0.0406 - val_mae: 0.1432
# Epoch 195/500
# 6/6 [==============================] - 4s 725ms/step - loss: 0.0393 - mae: 0.1483 - val_loss: 0.0346 - val_mae: 0.1341
# Epoch 196/500
# 6/6 [==============================] - 5s 760ms/step - loss: 0.0373 - mae: 0.1449 - val_loss: 0.0384 - val_mae: 0.1413
# Epoch 197/500
# 6/6 [==============================] - 4s 747ms/step - loss: 0.0431 - mae: 0.1534 - val_loss: 0.0340 - val_mae: 0.1340
# Epoch 198/500
# 6/6 [==============================] - 4s 739ms/step - loss: 0.0385 - mae: 0.1475 - val_loss: 0.0370 - val_mae: 0.1364
# Epoch 199/500
# 6/6 [==============================] - 4s 714ms/step - loss: 0.0378 - mae: 0.1451 - val_loss: 0.0331 - val_mae: 0.1302
# Epoch 200/500
# 6/6 [==============================] - 4s 754ms/step - loss: 0.0347 - mae: 0.1386 - val_loss: 0.0337 - val_mae: 0.1307
# Epoch 201/500
# 6/6 [==============================] - 4s 743ms/step - loss: 0.0382 - mae: 0.1445 - val_loss: 0.0394 - val_mae: 0.1421
# Epoch 202/500
# 6/6 [==============================] - 5s 757ms/step - loss: 0.0366 - mae: 0.1420 - val_loss: 0.0386 - val_mae: 0.1414
# Epoch 203/500
# 6/6 [==============================] - 4s 735ms/step - loss: 0.0402 - mae: 0.1499 - val_loss: 0.0303 - val_mae: 0.1235
# Epoch 204/500
# 6/6 [==============================] - 4s 715ms/step - loss: 0.0384 - mae: 0.1466 - val_loss: 0.0375 - val_mae: 0.1397
# Epoch 205/500
# 6/6 [==============================] - 4s 734ms/step - loss: 0.0386 - mae: 0.1454 - val_loss: 0.0415 - val_mae: 0.1476
# Epoch 206/500
# 6/6 [==============================] - 4s 739ms/step - loss: 0.0412 - mae: 0.1530 - val_loss: 0.0344 - val_mae: 0.1344
# Epoch 207/500
# 6/6 [==============================] - 4s 747ms/step - loss: 0.0395 - mae: 0.1498 - val_loss: 0.0414 - val_mae: 0.1469
# Epoch 208/500
# 6/6 [==============================] - 4s 727ms/step - loss: 0.0376 - mae: 0.1433 - val_loss: 0.0343 - val_mae: 0.1312
# Epoch 209/500
# 6/6 [==============================] - 4s 730ms/step - loss: 0.0414 - mae: 0.1521 - val_loss: 0.0354 - val_mae: 0.1363
# Epoch 210/500
# 6/6 [==============================] - 4s 722ms/step - loss: 0.0405 - mae: 0.1509 - val_loss: 0.0477 - val_mae: 0.1584
# Epoch 211/500
# 6/6 [==============================] - 4s 750ms/step - loss: 0.0388 - mae: 0.1467 - val_loss: 0.0335 - val_mae: 0.1301
# Epoch 212/500
# 6/6 [==============================] - 4s 752ms/step - loss: 0.0396 - mae: 0.1494 - val_loss: 0.0318 - val_mae: 0.1291
# Epoch 213/500
# 6/6 [==============================] - 4s 742ms/step - loss: 0.0370 - mae: 0.1447 - val_loss: 0.0406 - val_mae: 0.1463
# Epoch 214/500
# 6/6 [==============================] - 4s 721ms/step - loss: 0.0369 - mae: 0.1434 - val_loss: 0.0320 - val_mae: 0.1279
# Epoch 215/500
# 6/6 [==============================] - 4s 707ms/step - loss: 0.0384 - mae: 0.1469 - val_loss: 0.0332 - val_mae: 0.1297
# Epoch 216/500
# 6/6 [==============================] - 4s 748ms/step - loss: 0.0362 - mae: 0.1423 - val_loss: 0.0397 - val_mae: 0.1434
# Epoch 217/500
# 6/6 [==============================] - 5s 760ms/step - loss: 0.0363 - mae: 0.1416 - val_loss: 0.0359 - val_mae: 0.1355
# Epoch 218/500
# 6/6 [==============================] - 5s 765ms/step - loss: 0.0420 - mae: 0.1537 - val_loss: 0.0327 - val_mae: 0.1310
# Epoch 219/500
# 6/6 [==============================] - 4s 735ms/step - loss: 0.0362 - mae: 0.1415 - val_loss: 0.0397 - val_mae: 0.1416
# Epoch 220/500
# 6/6 [==============================] - 4s 724ms/step - loss: 0.0369 - mae: 0.1432 - val_loss: 0.0336 - val_mae: 0.1290
# Epoch 221/500
# 6/6 [==============================] - 5s 756ms/step - loss: 0.0379 - mae: 0.1458 - val_loss: 0.0315 - val_mae: 0.1256
# Epoch 222/500
# 6/6 [==============================] - 4s 731ms/step - loss: 0.0385 - mae: 0.1465 - val_loss: 0.0481 - val_mae: 0.1593
# Epoch 223/500
# 6/6 [==============================] - 4s 718ms/step - loss: 0.0367 - mae: 0.1426 - val_loss: 0.0376 - val_mae: 0.1374
# Epoch 224/500
# 6/6 [==============================] - 4s 729ms/step - loss: 0.0407 - mae: 0.1508 - val_loss: 0.0333 - val_mae: 0.1314
# Epoch 225/500
# 6/6 [==============================] - 4s 719ms/step - loss: 0.0375 - mae: 0.1458 - val_loss: 0.0404 - val_mae: 0.1459
# Epoch 226/500
# 6/6 [==============================] - 4s 715ms/step - loss: 0.0373 - mae: 0.1438 - val_loss: 0.0363 - val_mae: 0.1343
# Epoch 227/500
# 6/6 [==============================] - 4s 735ms/step - loss: 0.0383 - mae: 0.1462 - val_loss: 0.0342 - val_mae: 0.1333
# Epoch 228/500
# 6/6 [==============================] - 4s 723ms/step - loss: 0.0340 - mae: 0.1378 - val_loss: 0.0342 - val_mae: 0.1317
# Epoch 229/500
# 6/6 [==============================] - 4s 725ms/step - loss: 0.0340 - mae: 0.1358 - val_loss: 0.0342 - val_mae: 0.1309
# Epoch 230/500
# 6/6 [==============================] - 4s 725ms/step - loss: 0.0369 - mae: 0.1420 - val_loss: 0.0360 - val_mae: 0.1369
# Epoch 231/500
# 6/6 [==============================] - 4s 723ms/step - loss: 0.0335 - mae: 0.1361 - val_loss: 0.0373 - val_mae: 0.1349
# Epoch 232/500
# 6/6 [==============================] - 4s 740ms/step - loss: 0.0343 - mae: 0.1360 - val_loss: 0.0358 - val_mae: 0.1323
# Epoch 233/500
# 6/6 [==============================] - 4s 723ms/step - loss: 0.0369 - mae: 0.1425 - val_loss: 0.0360 - val_mae: 0.1372
# Epoch 234/500
# 6/6 [==============================] - 4s 718ms/step - loss: 0.0343 - mae: 0.1383 - val_loss: 0.0433 - val_mae: 0.1494
# Epoch 235/500
# 6/6 [==============================] - 5s 750ms/step - loss: 0.0368 - mae: 0.1425 - val_loss: 0.0313 - val_mae: 0.1256
# Epoch 236/500
# 6/6 [==============================] - 4s 712ms/step - loss: 0.0334 - mae: 0.1369 - val_loss: 0.0359 - val_mae: 0.1329
# Epoch 237/500
# 6/6 [==============================] - 4s 728ms/step - loss: 0.0353 - mae: 0.1385 - val_loss: 0.0373 - val_mae: 0.1380
# Epoch 238/500
# 6/6 [==============================] - 4s 726ms/step - loss: 0.0332 - mae: 0.1363 - val_loss: 0.0318 - val_mae: 0.1266
# Epoch 239/500
# 6/6 [==============================] - 4s 710ms/step - loss: 0.0321 - mae: 0.1327 - val_loss: 0.0383 - val_mae: 0.1372
# Epoch 240/500
# 6/6 [==============================] - 4s 728ms/step - loss: 0.0383 - mae: 0.1440 - val_loss: 0.0331 - val_mae: 0.1288
# Epoch 241/500
# 6/6 [==============================] - 4s 721ms/step - loss: 0.0374 - mae: 0.1452 - val_loss: 0.0410 - val_mae: 0.1459
# Epoch 242/500
# 6/6 [==============================] - 4s 735ms/step - loss: 0.0387 - mae: 0.1456 - val_loss: 0.0338 - val_mae: 0.1300
# Epoch 243/500
# 6/6 [==============================] - 4s 749ms/step - loss: 0.0376 - mae: 0.1454 - val_loss: 0.0414 - val_mae: 0.1472
# Epoch 244/500
# 6/6 [==============================] - 4s 737ms/step - loss: 0.0330 - mae: 0.1364 - val_loss: 0.0381 - val_mae: 0.1379
# Epoch 245/500
# 6/6 [==============================] - 4s 736ms/step - loss: 0.0383 - mae: 0.1434 - val_loss: 0.0304 - val_mae: 0.1232
# Epoch 246/500
# 6/6 [==============================] - 4s 741ms/step - loss: 0.0354 - mae: 0.1412 - val_loss: 0.0478 - val_mae: 0.1569
# Epoch 247/500
# 6/6 [==============================] - 5s 752ms/step - loss: 0.0379 - mae: 0.1452 - val_loss: 0.0360 - val_mae: 0.1358
# Epoch 248/500
# 6/6 [==============================] - 4s 717ms/step - loss: 0.0397 - mae: 0.1476 - val_loss: 0.0337 - val_mae: 0.1319
# Epoch 249/500
# 6/6 [==============================] - 4s 714ms/step - loss: 0.0366 - mae: 0.1444 - val_loss: 0.0441 - val_mae: 0.1517
# Epoch 250/500
# 6/6 [==============================] - 4s 747ms/step - loss: 0.0345 - mae: 0.1388 - val_loss: 0.0324 - val_mae: 0.1259
# Epoch 251/500
# 6/6 [==============================] - 4s 741ms/step - loss: 0.0355 - mae: 0.1391 - val_loss: 0.0339 - val_mae: 0.1301
# Epoch 252/500
# 6/6 [==============================] - 5s 746ms/step - loss: 0.0332 - mae: 0.1357 - val_loss: 0.0371 - val_mae: 0.1387
# Epoch 253/500
# 6/6 [==============================] - 4s 744ms/step - loss: 0.0350 - mae: 0.1386 - val_loss: 0.0327 - val_mae: 0.1265
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0436 - mae: 0.1473
# Loaded data with shape (4, 14800) and type float32
# Number of dyads: 2
# num_train_samples per dyad: 174
# num_val_samples per dyad: 58
# num_test_samples per dyad: 58
# Length of samples for each set: 348 116 116
# Model: "model_10"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_21 (InputLayer)          [(None, 250, 2)]     0           []
#
#  lstm_20 (LSTM)                 [(None, 100),        41200       ['input_21[0][0]']
#                                  (None, 100),
#                                  (None, 100)]
#
#  batch_normalization_20 (BatchN  (None, 100)         400         ['lstm_20[0][0]']
#  ormalization)
#
#  repeat_vector_10 (RepeatVector  (None, 100, 100)    0           ['batch_normalization_20[0][0]']
#  )
#
#  batch_normalization_21 (BatchN  (None, 100)         400         ['lstm_20[0][2]']
#  ormalization)
#
#  lstm_21 (LSTM)                 (None, 100, 100)     80400       ['repeat_vector_10[0][0]',
#                                                                   'batch_normalization_20[0][0]',
#                                                                   'batch_normalization_21[0][0]']
#
#  time_distributed_10 (TimeDistr  (None, 100, 2)      202         ['lstm_21[0][0]']
#  ibuted)
#
# ==================================================================================================
# Total params: 122,602
# Trainable params: 122,202
# Non-trainable params: 400
# __________________________________________________________________________________________________
# <keras.engine.functional.Functional object at 0x7f08cd9b1450>
# Epoch 1/500
# 6/6 [==============================] - 10s 820ms/step - loss: 0.2212 - mae: 0.3846 - val_loss: 0.1252 - val_mae: 0.3178
# Epoch 2/500
# 6/6 [==============================] - 4s 743ms/step - loss: 0.1449 - mae: 0.3288 - val_loss: 0.1256 - val_mae: 0.3169
# Epoch 3/500
# 6/6 [==============================] - 4s 726ms/step - loss: 0.1344 - mae: 0.3217 - val_loss: 0.1227 - val_mae: 0.3118
# Epoch 4/500
# 6/6 [==============================] - 4s 713ms/step - loss: 0.1273 - mae: 0.3133 - val_loss: 0.1204 - val_mae: 0.3082
# Epoch 5/500
# 6/6 [==============================] - 4s 728ms/step - loss: 0.1246 - mae: 0.3115 - val_loss: 0.1188 - val_mae: 0.3067
# Epoch 6/500
# 6/6 [==============================] - 4s 722ms/step - loss: 0.1229 - mae: 0.3099 - val_loss: 0.1175 - val_mae: 0.3041
# Epoch 7/500
# 6/6 [==============================] - 4s 738ms/step - loss: 0.1213 - mae: 0.3073 - val_loss: 0.1159 - val_mae: 0.3017
# Epoch 8/500
# 6/6 [==============================] - 4s 733ms/step - loss: 0.1195 - mae: 0.3046 - val_loss: 0.1148 - val_mae: 0.2994
# Epoch 9/500
# 6/6 [==============================] - 4s 727ms/step - loss: 0.1182 - mae: 0.3026 - val_loss: 0.1132 - val_mae: 0.2973
# Epoch 10/500
# 6/6 [==============================] - 4s 730ms/step - loss: 0.1166 - mae: 0.3002 - val_loss: 0.1122 - val_mae: 0.2950
# Epoch 11/500
# 6/6 [==============================] - 4s 749ms/step - loss: 0.1161 - mae: 0.2987 - val_loss: 0.1118 - val_mae: 0.2934
# Epoch 12/500
# 6/6 [==============================] - 4s 729ms/step - loss: 0.1144 - mae: 0.2957 - val_loss: 0.1112 - val_mae: 0.2918
# Epoch 13/500
# 6/6 [==============================] - 4s 754ms/step - loss: 0.1137 - mae: 0.2943 - val_loss: 0.1102 - val_mae: 0.2894
# Epoch 14/500
# 6/6 [==============================] - 4s 713ms/step - loss: 0.1122 - mae: 0.2922 - val_loss: 0.1085 - val_mae: 0.2868
# Epoch 15/500
# 6/6 [==============================] - 4s 723ms/step - loss: 0.1113 - mae: 0.2904 - val_loss: 0.1067 - val_mae: 0.2833
# Epoch 16/500
# 6/6 [==============================] - 4s 750ms/step - loss: 0.1109 - mae: 0.2890 - val_loss: 0.1058 - val_mae: 0.2820
# Epoch 17/500
# 6/6 [==============================] - 4s 734ms/step - loss: 0.1099 - mae: 0.2876 - val_loss: 0.1039 - val_mae: 0.2796
# Epoch 18/500
# 6/6 [==============================] - 4s 728ms/step - loss: 0.1080 - mae: 0.2850 - val_loss: 0.1019 - val_mae: 0.2753
# Epoch 19/500
# 6/6 [==============================] - 4s 719ms/step - loss: 0.1063 - mae: 0.2812 - val_loss: 0.0999 - val_mae: 0.2701
# Epoch 20/500
# 6/6 [==============================] - 4s 726ms/step - loss: 0.1039 - mae: 0.2767 - val_loss: 0.0970 - val_mae: 0.2641
# Epoch 21/500
# 6/6 [==============================] - 4s 720ms/step - loss: 0.1014 - mae: 0.2718 - val_loss: 0.0927 - val_mae: 0.2565
# Epoch 22/500
# 6/6 [==============================] - 4s 724ms/step - loss: 0.0978 - mae: 0.2654 - val_loss: 0.0896 - val_mae: 0.2521
# Epoch 23/500
# 6/6 [==============================] - 4s 720ms/step - loss: 0.0946 - mae: 0.2596 - val_loss: 0.0809 - val_mae: 0.2350
# Epoch 24/500
# 6/6 [==============================] - 4s 748ms/step - loss: 0.0903 - mae: 0.2494 - val_loss: 0.0838 - val_mae: 0.2423
# Epoch 25/500
# 6/6 [==============================] - 5s 753ms/step - loss: 0.0862 - mae: 0.2446 - val_loss: 0.0660 - val_mae: 0.2014
# Epoch 26/500
# 6/6 [==============================] - 4s 727ms/step - loss: 0.0813 - mae: 0.2298 - val_loss: 0.0637 - val_mae: 0.2034
# Epoch 27/500
# 6/6 [==============================] - 4s 740ms/step - loss: 0.0818 - mae: 0.2334 - val_loss: 0.0594 - val_mae: 0.1973
# Epoch 28/500
# 6/6 [==============================] - 4s 744ms/step - loss: 0.0773 - mae: 0.2233 - val_loss: 0.0561 - val_mae: 0.1866
# Epoch 29/500
# 6/6 [==============================] - 5s 762ms/step - loss: 0.0751 - mae: 0.2193 - val_loss: 0.0569 - val_mae: 0.1899
# Epoch 30/500
# 6/6 [==============================] - 4s 712ms/step - loss: 0.0738 - mae: 0.2178 - val_loss: 0.0537 - val_mae: 0.1813
# Epoch 31/500
# 6/6 [==============================] - 4s 738ms/step - loss: 0.0692 - mae: 0.2064 - val_loss: 0.0488 - val_mae: 0.1735
# Epoch 32/500
# 6/6 [==============================] - 4s 733ms/step - loss: 0.0701 - mae: 0.2105 - val_loss: 0.0477 - val_mae: 0.1713
# Epoch 33/500
# 6/6 [==============================] - 4s 727ms/step - loss: 0.0676 - mae: 0.2055 - val_loss: 0.0483 - val_mae: 0.1711
# Epoch 34/500
# 6/6 [==============================] - 4s 715ms/step - loss: 0.0690 - mae: 0.2072 - val_loss: 0.0494 - val_mae: 0.1737
# Epoch 35/500
# 6/6 [==============================] - 4s 732ms/step - loss: 0.0668 - mae: 0.2045 - val_loss: 0.0496 - val_mae: 0.1745
# Epoch 36/500
# 6/6 [==============================] - 4s 728ms/step - loss: 0.0682 - mae: 0.2055 - val_loss: 0.0495 - val_mae: 0.1738
# Epoch 37/500
# 6/6 [==============================] - 5s 757ms/step - loss: 0.0659 - mae: 0.2027 - val_loss: 0.0502 - val_mae: 0.1718
# Epoch 38/500
# 6/6 [==============================] - 5s 757ms/step - loss: 0.0642 - mae: 0.1985 - val_loss: 0.0461 - val_mae: 0.1667
# Epoch 39/500
# 6/6 [==============================] - 5s 765ms/step - loss: 0.0665 - mae: 0.2006 - val_loss: 0.0469 - val_mae: 0.1662
# Epoch 40/500
# 6/6 [==============================] - 4s 733ms/step - loss: 0.0640 - mae: 0.2007 - val_loss: 0.0471 - val_mae: 0.1695
# Epoch 41/500
# 6/6 [==============================] - 4s 759ms/step - loss: 0.0674 - mae: 0.2021 - val_loss: 0.0468 - val_mae: 0.1686
# Epoch 42/500
# 6/6 [==============================] - 4s 713ms/step - loss: 0.0637 - mae: 0.1992 - val_loss: 0.0461 - val_mae: 0.1654
# Epoch 43/500
# 6/6 [==============================] - 4s 723ms/step - loss: 0.0656 - mae: 0.1998 - val_loss: 0.0476 - val_mae: 0.1695
# Epoch 44/500
# 6/6 [==============================] - 4s 756ms/step - loss: 0.0661 - mae: 0.2036 - val_loss: 0.0473 - val_mae: 0.1670
# Epoch 45/500
# 6/6 [==============================] - 4s 736ms/step - loss: 0.0633 - mae: 0.1965 - val_loss: 0.0488 - val_mae: 0.1699
# Epoch 46/500
# 6/6 [==============================] - 4s 722ms/step - loss: 0.0659 - mae: 0.2006 - val_loss: 0.0470 - val_mae: 0.1683
# Epoch 47/500
# 6/6 [==============================] - 5s 760ms/step - loss: 0.0615 - mae: 0.1947 - val_loss: 0.0458 - val_mae: 0.1636
# Epoch 48/500
# 6/6 [==============================] - 4s 726ms/step - loss: 0.0640 - mae: 0.1967 - val_loss: 0.0449 - val_mae: 0.1629
# Epoch 49/500
# 6/6 [==============================] - 4s 744ms/step - loss: 0.0636 - mae: 0.1990 - val_loss: 0.0445 - val_mae: 0.1627
# Epoch 50/500
# 6/6 [==============================] - 4s 725ms/step - loss: 0.0612 - mae: 0.1926 - val_loss: 0.0453 - val_mae: 0.1646
# Epoch 51/500
# 6/6 [==============================] - 4s 731ms/step - loss: 0.0599 - mae: 0.1907 - val_loss: 0.0451 - val_mae: 0.1624
# Epoch 52/500
# 6/6 [==============================] - 4s 728ms/step - loss: 0.0631 - mae: 0.1954 - val_loss: 0.0448 - val_mae: 0.1636
# Epoch 53/500
# 6/6 [==============================] - 4s 746ms/step - loss: 0.0628 - mae: 0.1977 - val_loss: 0.0467 - val_mae: 0.1645
# Epoch 54/500
# 6/6 [==============================] - 4s 730ms/step - loss: 0.0623 - mae: 0.1929 - val_loss: 0.0457 - val_mae: 0.1639
# Epoch 55/500
# 6/6 [==============================] - 5s 771ms/step - loss: 0.0619 - mae: 0.1961 - val_loss: 0.0470 - val_mae: 0.1666
# Epoch 56/500
# 6/6 [==============================] - 4s 742ms/step - loss: 0.0620 - mae: 0.1943 - val_loss: 0.0448 - val_mae: 0.1594
# Epoch 57/500
# 6/6 [==============================] - 5s 763ms/step - loss: 0.0616 - mae: 0.1933 - val_loss: 0.0435 - val_mae: 0.1591
# Epoch 58/500
# 6/6 [==============================] - 4s 724ms/step - loss: 0.0600 - mae: 0.1897 - val_loss: 0.0442 - val_mae: 0.1587
# Epoch 59/500
# 6/6 [==============================] - 4s 716ms/step - loss: 0.0631 - mae: 0.1960 - val_loss: 0.0461 - val_mae: 0.1619
# Epoch 60/500
# 6/6 [==============================] - 4s 718ms/step - loss: 0.0602 - mae: 0.1916 - val_loss: 0.0440 - val_mae: 0.1593
# Epoch 61/500
# 6/6 [==============================] - 4s 710ms/step - loss: 0.0602 - mae: 0.1902 - val_loss: 0.0431 - val_mae: 0.1570
# Epoch 62/500
# 6/6 [==============================] - 4s 745ms/step - loss: 0.0608 - mae: 0.1920 - val_loss: 0.0448 - val_mae: 0.1612
# Epoch 63/500
# 6/6 [==============================] - 4s 720ms/step - loss: 0.0590 - mae: 0.1876 - val_loss: 0.0441 - val_mae: 0.1596
# Epoch 64/500
# ...
# Epoch 171/500
# 6/6 [==============================] - 5s 785ms/step - loss: 0.0423 - mae: 0.1553 - val_loss: 0.0295 - val_mae: 0.1232
# Epoch 172/500
# 6/6 [==============================] - 5s 794ms/step - loss: 0.0419 - mae: 0.1538 - val_loss: 0.0313 - val_mae: 0.1308
# Epoch 173/500
# 6/6 [==============================] - 4s 727ms/step - loss: 0.0423 - mae: 0.1532 - val_loss: 0.0374 - val_mae: 0.1437
# Epoch 174/500
# 6/6 [==============================] - 4s 752ms/step - loss: 0.0435 - mae: 0.1575 - val_loss: 0.0329 - val_mae: 0.1336
# Epoch 175/500
# 6/6 [==============================] - 5s 751ms/step - loss: 0.0437 - mae: 0.1577 - val_loss: 0.0308 - val_mae: 0.1274
# Epoch 176/500
# 6/6 [==============================] - 4s 723ms/step - loss: 0.0407 - mae: 0.1502 - val_loss: 0.0348 - val_mae: 0.1364
# Epoch 177/500
# 6/6 [==============================] - 4s 743ms/step - loss: 0.0423 - mae: 0.1535 - val_loss: 0.0319 - val_mae: 0.1312
# Epoch 178/500
# 6/6 [==============================] - 4s 727ms/step - loss: 0.0408 - mae: 0.1520 - val_loss: 0.0339 - val_mae: 0.1342
# Epoch 179/500
# 6/6 [==============================] - 4s 729ms/step - loss: 0.0414 - mae: 0.1534 - val_loss: 0.0336 - val_mae: 0.1357
# Epoch 180/500
# 6/6 [==============================] - 5s 761ms/step - loss: 0.0429 - mae: 0.1555 - val_loss: 0.0321 - val_mae: 0.1301
# Epoch 181/500
# 6/6 [==============================] - 4s 753ms/step - loss: 0.0410 - mae: 0.1503 - val_loss: 0.0307 - val_mae: 0.1291
# Epoch 182/500
# 6/6 [==============================] - 4s 732ms/step - loss: 0.0422 - mae: 0.1550 - val_loss: 0.0302 - val_mae: 0.1288
# Epoch 183/500
# 6/6 [==============================] - 4s 735ms/step - loss: 0.0411 - mae: 0.1538 - val_loss: 0.0384 - val_mae: 0.1455
# Epoch 184/500
# 6/6 [==============================] - 4s 725ms/step - loss: 0.0438 - mae: 0.1563 - val_loss: 0.0313 - val_mae: 0.1299
# Epoch 185/500
# 6/6 [==============================] - 5s 750ms/step - loss: 0.0397 - mae: 0.1501 - val_loss: 0.0332 - val_mae: 0.1322
# Epoch 186/500
# 6/6 [==============================] - 4s 736ms/step - loss: 0.0432 - mae: 0.1535 - val_loss: 0.0437 - val_mae: 0.1526
# Epoch 187/500
# 6/6 [==============================] - 4s 747ms/step - loss: 0.0474 - mae: 0.1648 - val_loss: 0.0333 - val_mae: 0.1380
# Epoch 188/500
# 6/6 [==============================] - 5s 772ms/step - loss: 0.0444 - mae: 0.1608 - val_loss: 0.0330 - val_mae: 0.1320
# Epoch 189/500
# 6/6 [==============================] - 4s 736ms/step - loss: 0.0418 - mae: 0.1503 - val_loss: 0.0374 - val_mae: 0.1431
# Epoch 190/500
# 6/6 [==============================] - 5s 768ms/step - loss: 0.0403 - mae: 0.1505 - val_loss: 0.0306 - val_mae: 0.1253
# Epoch 191/500
# 6/6 [==============================] - 5s 765ms/step - loss: 0.0410 - mae: 0.1522 - val_loss: 0.0295 - val_mae: 0.1263
# Epoch 192/500
# 6/6 [==============================] - 4s 734ms/step - loss: 0.0402 - mae: 0.1486 - val_loss: 0.0301 - val_mae: 0.1263
# Epoch 193/500
# 6/6 [==============================] - 4s 742ms/step - loss: 0.0402 - mae: 0.1507 - val_loss: 0.0362 - val_mae: 0.1364
# Epoch 194/500
# 6/6 [==============================] - 4s 748ms/step - loss: 0.0406 - mae: 0.1509 - val_loss: 0.0349 - val_mae: 0.1378
# Epoch 195/500
# 6/6 [==============================] - 4s 749ms/step - loss: 0.0408 - mae: 0.1509 - val_loss: 0.0346 - val_mae: 0.1315
# Epoch 196/500
# 6/6 [==============================] - 5s 768ms/step - loss: 0.0401 - mae: 0.1490 - val_loss: 0.0397 - val_mae: 0.1464
# Epoch 197/500
# 6/6 [==============================] - 5s 806ms/step - loss: 0.0435 - mae: 0.1570 - val_loss: 0.0300 - val_mae: 0.1278
# Epoch 198/500
# 6/6 [==============================] - 4s 746ms/step - loss: 0.0426 - mae: 0.1566 - val_loss: 0.0357 - val_mae: 0.1363
# Epoch 199/500
# 6/6 [==============================] - 5s 786ms/step - loss: 0.0421 - mae: 0.1515 - val_loss: 0.0325 - val_mae: 0.1321
# Epoch 200/500
# 6/6 [==============================] - 4s 730ms/step - loss: 0.0414 - mae: 0.1539 - val_loss: 0.0300 - val_mae: 0.1251
# Epoch 201/500
# 6/6 [==============================] - 4s 736ms/step - loss: 0.0401 - mae: 0.1495 - val_loss: 0.0349 - val_mae: 0.1382
# Epoch 202/500
# 6/6 [==============================] - 4s 749ms/step - loss: 0.0385 - mae: 0.1456 - val_loss: 0.0363 - val_mae: 0.1372
# Epoch 203/500
# 6/6 [==============================] - 4s 733ms/step - loss: 0.0403 - mae: 0.1503 - val_loss: 0.0306 - val_mae: 0.1294
# Epoch 204/500
# 6/6 [==============================] - 4s 741ms/step - loss: 0.0383 - mae: 0.1472 - val_loss: 0.0302 - val_mae: 0.1253
# Epoch 205/500
# 6/6 [==============================] - 4s 752ms/step - loss: 0.0399 - mae: 0.1482 - val_loss: 0.0307 - val_mae: 0.1264
# Epoch 206/500
# 6/6 [==============================] - 4s 724ms/step - loss: 0.0393 - mae: 0.1473 - val_loss: 0.0298 - val_mae: 0.1244
# Epoch 207/500
# 6/6 [==============================] - 4s 757ms/step - loss: 0.0391 - mae: 0.1471 - val_loss: 0.0296 - val_mae: 0.1262
# Epoch 208/500
# 6/6 [==============================] - 4s 746ms/step - loss: 0.0408 - mae: 0.1500 - val_loss: 0.0348 - val_mae: 0.1350
# Epoch 209/500
# 6/6 [==============================] - 4s 740ms/step - loss: 0.0383 - mae: 0.1456 - val_loss: 0.0283 - val_mae: 0.1218
# Epoch 210/500
# 6/6 [==============================] - 5s 753ms/step - loss: 0.0367 - mae: 0.1419 - val_loss: 0.0324 - val_mae: 0.1310
# Epoch 211/500
# 6/6 [==============================] - 4s 753ms/step - loss: 0.0397 - mae: 0.1481 - val_loss: 0.0307 - val_mae: 0.1277
# Epoch 212/500
# 6/6 [==============================] - 4s 745ms/step - loss: 0.0370 - mae: 0.1442 - val_loss: 0.0321 - val_mae: 0.1318
# Epoch 213/500
# 6/6 [==============================] - 4s 734ms/step - loss: 0.0380 - mae: 0.1431 - val_loss: 0.0316 - val_mae: 0.1297
# Epoch 214/500
# 6/6 [==============================] - 4s 737ms/step - loss: 0.0390 - mae: 0.1473 - val_loss: 0.0359 - val_mae: 0.1383
# Epoch 215/500
# 6/6 [==============================] - 4s 740ms/step - loss: 0.0394 - mae: 0.1495 - val_loss: 0.0339 - val_mae: 0.1319
# Epoch 216/500
# 6/6 [==============================] - 5s 746ms/step - loss: 0.0384 - mae: 0.1458 - val_loss: 0.0328 - val_mae: 0.1307
# Epoch 217/500
# 6/6 [==============================] - 4s 751ms/step - loss: 0.0378 - mae: 0.1441 - val_loss: 0.0383 - val_mae: 0.1410
# Epoch 218/500
# 6/6 [==============================] - 5s 773ms/step - loss: 0.0412 - mae: 0.1506 - val_loss: 0.0362 - val_mae: 0.1415
# Epoch 219/500
# 6/6 [==============================] - 5s 761ms/step - loss: 0.0401 - mae: 0.1504 - val_loss: 0.0323 - val_mae: 0.1312
# Epoch 220/500
# 6/6 [==============================] - 4s 725ms/step - loss: 0.0379 - mae: 0.1463 - val_loss: 0.0301 - val_mae: 0.1251
# Epoch 221/500
# 6/6 [==============================] - 4s 719ms/step - loss: 0.0370 - mae: 0.1411 - val_loss: 0.0361 - val_mae: 0.1355
# Epoch 222/500
# 6/6 [==============================] - 4s 735ms/step - loss: 0.0375 - mae: 0.1443 - val_loss: 0.0314 - val_mae: 0.1276
# Epoch 223/500
# 6/6 [==============================] - 5s 752ms/step - loss: 0.0387 - mae: 0.1471 - val_loss: 0.0321 - val_mae: 0.1302
# Epoch 224/500
# 6/6 [==============================] - 4s 739ms/step - loss: 0.0390 - mae: 0.1475 - val_loss: 0.0358 - val_mae: 0.1385
# Epoch 225/500
# 6/6 [==============================] - 4s 743ms/step - loss: 0.0370 - mae: 0.1429 - val_loss: 0.0316 - val_mae: 0.1284
# Epoch 226/500
# 6/6 [==============================] - 4s 742ms/step - loss: 0.0347 - mae: 0.1371 - val_loss: 0.0312 - val_mae: 0.1266
# Epoch 227/500
# 6/6 [==============================] - 5s 763ms/step - loss: 0.0372 - mae: 0.1443 - val_loss: 0.0294 - val_mae: 0.1243
# Epoch 228/500
# 6/6 [==============================] - 5s 754ms/step - loss: 0.0356 - mae: 0.1395 - val_loss: 0.0308 - val_mae: 0.1248
# Epoch 229/500
# 6/6 [==============================] - 5s 756ms/step - loss: 0.0358 - mae: 0.1404 - val_loss: 0.0327 - val_mae: 0.1305
# Epoch 230/500
# 6/6 [==============================] - 5s 771ms/step - loss: 0.0359 - mae: 0.1392 - val_loss: 0.0329 - val_mae: 0.1315
# Epoch 231/500
# 6/6 [==============================] - 4s 741ms/step - loss: 0.0358 - mae: 0.1417 - val_loss: 0.0322 - val_mae: 0.1278
# Epoch 232/500
# 6/6 [==============================] - 4s 723ms/step - loss: 0.0365 - mae: 0.1410 - val_loss: 0.0311 - val_mae: 0.1254
# Epoch 233/500
# 6/6 [==============================] - 5s 762ms/step - loss: 0.0345 - mae: 0.1371 - val_loss: 0.0335 - val_mae: 0.1295
# Epoch 234/500
# 6/6 [==============================] - 5s 763ms/step - loss: 0.0355 - mae: 0.1406 - val_loss: 0.0302 - val_mae: 0.1233
# Epoch 235/500
# 6/6 [==============================] - 4s 722ms/step - loss: 0.0359 - mae: 0.1392 - val_loss: 0.0316 - val_mae: 0.1274
# Epoch 236/500
# 6/6 [==============================] - 4s 734ms/step - loss: 0.0386 - mae: 0.1456 - val_loss: 0.0351 - val_mae: 0.1345
# Epoch 237/500
# 6/6 [==============================] - 4s 730ms/step - loss: 0.0359 - mae: 0.1420 - val_loss: 0.0322 - val_mae: 0.1278
# Epoch 238/500
# 6/6 [==============================] - 4s 732ms/step - loss: 0.0369 - mae: 0.1418 - val_loss: 0.0326 - val_mae: 0.1311
# Epoch 239/500
# 6/6 [==============================] - 4s 740ms/step - loss: 0.0361 - mae: 0.1416 - val_loss: 0.0279 - val_mae: 0.1181
# Epoch 240/500
# 6/6 [==============================] - 5s 755ms/step - loss: 0.0363 - mae: 0.1404 - val_loss: 0.0311 - val_mae: 0.1255
# Epoch 241/500
# 6/6 [==============================] - 4s 731ms/step - loss: 0.0356 - mae: 0.1402 - val_loss: 0.0361 - val_mae: 0.1371
# Epoch 242/500
# 6/6 [==============================] - 4s 743ms/step - loss: 0.0364 - mae: 0.1416 - val_loss: 0.0325 - val_mae: 0.1296
# Epoch 243/500
# 6/6 [==============================] - 4s 744ms/step - loss: 0.0351 - mae: 0.1365 - val_loss: 0.0363 - val_mae: 0.1369
# Epoch 244/500
# 6/6 [==============================] - 4s 736ms/step - loss: 0.0360 - mae: 0.1417 - val_loss: 0.0317 - val_mae: 0.1277
# Epoch 245/500
# 6/6 [==============================] - 4s 726ms/step - loss: 0.0340 - mae: 0.1362 - val_loss: 0.0311 - val_mae: 0.1247
# Epoch 246/500
# 6/6 [==============================] - 5s 750ms/step - loss: 0.0342 - mae: 0.1346 - val_loss: 0.0336 - val_mae: 0.1330
# Epoch 247/500
# 6/6 [==============================] - 4s 759ms/step - loss: 0.0364 - mae: 0.1417 - val_loss: 0.0306 - val_mae: 0.1221
# Epoch 248/500
# 6/6 [==============================] - 5s 783ms/step - loss: 0.0346 - mae: 0.1382 - val_loss: 0.0309 - val_mae: 0.1255
# Epoch 249/500
# 6/6 [==============================] - 4s 738ms/step - loss: 0.0367 - mae: 0.1406 - val_loss: 0.0389 - val_mae: 0.1433
# Epoch 250/500
# 6/6 [==============================] - 4s 723ms/step - loss: 0.0356 - mae: 0.1411 - val_loss: 0.0329 - val_mae: 0.1281
# Epoch 251/500
# 6/6 [==============================] - 4s 742ms/step - loss: 0.0346 - mae: 0.1366 - val_loss: 0.0391 - val_mae: 0.1445
# Epoch 252/500
# 6/6 [==============================] - 5s 767ms/step - loss: 0.0374 - mae: 0.1437 - val_loss: 0.0323 - val_mae: 0.1247
# Epoch 253/500
# 6/6 [==============================] - 4s 742ms/step - loss: 0.0364 - mae: 0.1417 - val_loss: 0.0322 - val_mae: 0.1282
# Epoch 254/500
# 6/6 [==============================] - 4s 749ms/step - loss: 0.0343 - mae: 0.1372 - val_loss: 0.0311 - val_mae: 0.1253
# Epoch 255/500
# 6/6 [==============================] - 5s 773ms/step - loss: 0.0342 - mae: 0.1374 - val_loss: 0.0306 - val_mae: 0.1232
# Epoch 256/500
# 6/6 [==============================] - 4s 740ms/step - loss: 0.0345 - mae: 0.1359 - val_loss: 0.0328 - val_mae: 0.1288
# Epoch 257/500
# 6/6 [==============================] - 5s 776ms/step - loss: 0.0328 - mae: 0.1348 - val_loss: 0.0367 - val_mae: 0.1353
# Epoch 258/500
# 6/6 [==============================] - 5s 783ms/step - loss: 0.0343 - mae: 0.1356 - val_loss: 0.0317 - val_mae: 0.1287
# Epoch 259/500
# 6/6 [==============================] - 5s 776ms/step - loss: 0.0349 - mae: 0.1377 - val_loss: 0.0401 - val_mae: 0.1415
# Epoch 260/500
# 6/6 [==============================] - 4s 732ms/step - loss: 0.0371 - mae: 0.1420 - val_loss: 0.0328 - val_mae: 0.1300
# Epoch 261/500
# 6/6 [==============================] - 4s 750ms/step - loss: 0.0383 - mae: 0.1435 - val_loss: 0.0388 - val_mae: 0.1452
# Epoch 262/500
# 6/6 [==============================] - 4s 728ms/step - loss: 0.0372 - mae: 0.1458 - val_loss: 0.0359 - val_mae: 0.1338
# Epoch 263/500
# 6/6 [==============================] - 5s 774ms/step - loss: 0.0336 - mae: 0.1356 - val_loss: 0.0308 - val_mae: 0.1256
# Epoch 264/500
# 6/6 [==============================] - 4s 754ms/step - loss: 0.0339 - mae: 0.1362 - val_loss: 0.0312 - val_mae: 0.1252
# Epoch 265/500
# 6/6 [==============================] - 5s 759ms/step - loss: 0.0343 - mae: 0.1377 - val_loss: 0.0339 - val_mae: 0.1324
# Epoch 266/500
# 6/6 [==============================] - 5s 760ms/step - loss: 0.0361 - mae: 0.1409 - val_loss: 0.0368 - val_mae: 0.1370
# Epoch 267/500
# 6/6 [==============================] - 4s 745ms/step - loss: 0.0343 - mae: 0.1376 - val_loss: 0.0345 - val_mae: 0.1294
# Epoch 268/500
# 6/6 [==============================] - 4s 747ms/step - loss: 0.0363 - mae: 0.1397 - val_loss: 0.0432 - val_mae: 0.1511
# Epoch 269/500
# 6/6 [==============================] - 4s 745ms/step - loss: 0.0359 - mae: 0.1409 - val_loss: 0.0387 - val_mae: 0.1408
# Epoch 270/500
# 6/6 [==============================] - 5s 777ms/step - loss: 0.0353 - mae: 0.1400 - val_loss: 0.0385 - val_mae: 0.1397
# Epoch 271/500
# 6/6 [==============================] - 4s 730ms/step - loss: 0.0368 - mae: 0.1404 - val_loss: 0.0342 - val_mae: 0.1316
# Epoch 272/500
# 6/6 [==============================] - 4s 727ms/step - loss: 0.0349 - mae: 0.1377 - val_loss: 0.0339 - val_mae: 0.1312
# Epoch 273/500
# 6/6 [==============================] - 4s 735ms/step - loss: 0.0345 - mae: 0.1378 - val_loss: 0.0303 - val_mae: 0.1234
# Epoch 274/500
# 6/6 [==============================] - 5s 773ms/step - loss: 0.0338 - mae: 0.1358 - val_loss: 0.0289 - val_mae: 0.1212
# Epoch 275/500
# 6/6 [==============================] - 5s 746ms/step - loss: 0.0335 - mae: 0.1347 - val_loss: 0.0408 - val_mae: 0.1442
# Epoch 276/500
# 6/6 [==============================] - 5s 766ms/step - loss: 0.0364 - mae: 0.1398 - val_loss: 0.0337 - val_mae: 0.1314
# Epoch 277/500
# 6/6 [==============================] - 5s 768ms/step - loss: 0.0345 - mae: 0.1383 - val_loss: 0.0307 - val_mae: 0.1240
# Epoch 278/500
# 6/6 [==============================] - 5s 761ms/step - loss: 0.0330 - mae: 0.1337 - val_loss: 0.0377 - val_mae: 0.1367
# Epoch 279/500
# 6/6 [==============================] - 4s 733ms/step - loss: 0.0361 - mae: 0.1403 - val_loss: 0.0322 - val_mae: 0.1255
# Epoch 280/500
# 6/6 [==============================] - 4s 738ms/step - loss: 0.0320 - mae: 0.1327 - val_loss: 0.0292 - val_mae: 0.1211
# Epoch 281/500
# 6/6 [==============================] - 4s 727ms/step - loss: 0.0319 - mae: 0.1307 - val_loss: 0.0326 - val_mae: 0.1248
# Epoch 282/500
# 6/6 [==============================] - 4s 749ms/step - loss: 0.0325 - mae: 0.1317 - val_loss: 0.0296 - val_mae: 0.1212
# Epoch 283/500
# 6/6 [==============================] - 4s 725ms/step - loss: 0.0323 - mae: 0.1342 - val_loss: 0.0292 - val_mae: 0.1193
# Epoch 284/500
# 6/6 [==============================] - 5s 759ms/step - loss: 0.0290 - mae: 0.1256 - val_loss: 0.0313 - val_mae: 0.1237
# Epoch 285/500
# 6/6 [==============================] - 4s 749ms/step - loss: 0.0325 - mae: 0.1325 - val_loss: 0.0324 - val_mae: 0.1274
# Epoch 286/500
# 6/6 [==============================] - 4s 740ms/step - loss: 0.0332 - mae: 0.1355 - val_loss: 0.0287 - val_mae: 0.1192
# Epoch 287/500
# 6/6 [==============================] - 5s 760ms/step - loss: 0.0321 - mae: 0.1314 - val_loss: 0.0286 - val_mae: 0.1194
# Epoch 288/500
# 6/6 [==============================] - 4s 725ms/step - loss: 0.0318 - mae: 0.1307 - val_loss: 0.0318 - val_mae: 0.1246
# Epoch 289/500
# 6/6 [==============================] - 5s 776ms/step - loss: 0.0306 - mae: 0.1283 - val_loss: 0.0323 - val_mae: 0.1254
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0347 - mae: 0.1319

# %%
for x in trial: print(data_all[x]["results_all"])
# Out:
# {'sit': [0.04362959787249565, 0.14726123213768005], 'gaze': [0.030924485996365547, 0.12523052096366882], 'gaze_swap': [0.034299299120903015, 0.13102079927921295]}
# {'sit': [0.04553426429629326, 0.15072990953922272], 'gaze': [0.03611404448747635, 0.13419637084007263], 'gaze_swap': [0.03472951799631119, 0.13194513320922852]}

# %%
# save dictionary as pickle file
with open('data_all.pickle', 'wb') as handle:
    pickle.dump(data_all, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
if google_colab == 1:
  from google.colab import files
  files.download('data_all.pickle')
  for x in list(data_all.keys()):
    for y in list(data_all[x]["model_all"].keys()):
      files.download((data_all[x]["model_all"][y]))
    # load.model(...)
